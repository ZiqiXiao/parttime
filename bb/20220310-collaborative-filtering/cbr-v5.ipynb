# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %%
def get_movie_dataset():
    # 加载基于所有电影的标签
    # all-tag.csv
    _tags = pd.read_csv("ml-latest-small/tags.csv", usecols=range(1, 3)).dropna()
    tags = _tags.groupby("movieId").agg(list)

    # 加载电影列表数据
    movies = pd.read_csv("ml-latest-small/movies.csv", index_col="movieId")
    # 将电影的类别词分开
    movies['genres'] = movies['genres'].apply(lambda x: x.split("|"))

    # 为每部电影匹配对应的标签数据， 如果没有将会是NAN
    movies_index = set(movies.index) & set(tags.index)
    new_tags = tags.loc[list(movies_index)]
    ret = movies.join(new_tags)

    # 构建电影数据集， 包含电影ID， 电影名称， 类别和标签四个字段
    # 如果电影没有标签数据， 就替换为空列表
    # map(fun, 可迭代对象)
    df = map(lambda x: (x[0], x[1], x[2], x[2]+x[3]) if x[3] is not np.nan else (x[0], x[1], x[2], []), ret.itertuples())
    movies_dataset = pd.DataFrame(df, columns=['movieId', 'title', 'genres', 'tags'])

    movies_dataset.set_index("movieId", inplace=True)
    return movies_dataset

movies_dataset = get_movie_dataset()
movies_dataset.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                                     genres  \
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]
# 2                           [Adventure, Children, Fantasy]
# 3                                        [Comedy, Romance]
# 4                                 [Comedy, Drama, Romance]
# 5                                                 [Comedy]
#
#                                                       tags
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fanta...
# 2        [Adventure, Children, Fantasy, fantasy, magic ...
# 3                            [Comedy, Romance, moldy, old]
# 4                                                       []
# 5                              [Comedy, pregnancy, remake]

# %%
from gensim.models import TfidfModel
from pprint import pprint
from gensim.corpora import Dictionary

def create_movie_profile(movie_dataset):
    '''
    使用tfidf，分析提取topn关键词
    :param movie_dataset:
    :return:
    '''
    dataset = movie_dataset["tags"].values

    from gensim.corpora import Dictionary
    # 根据数据集建立词袋，并统计词频，将所有词放入一个词典，使用索引进行获取
    dct = Dictionary(dataset)
    # 根据将每条数据，返回对应的词索引和词频
    corpus = [dct.doc2bow(line) for line in dataset]
    # 训练TF-IDF模型，即计算TF-IDF值
    model = TfidfModel(corpus)

    _movie_profile = []
    for i, data in enumerate(movie_dataset.itertuples()):
        mid = data[0]
        title = data[1]
        genres = data[2]
        vector = model[corpus[i]]
        movie_tags = sorted(vector, key=lambda x: x[1], reverse=True)[:30]
        topN_tags_weights = dict(map(lambda x: (dct[x[0]], x[1]), movie_tags))
        # 将类别词的添加进去，并设置权重值为1.0
        for g in genres:
            topN_tags_weights[g] = 1.0
        topN_tags = [i[0] for i in topN_tags_weights.items()]
        _movie_profile.append((mid, title, topN_tags, topN_tags_weights))

    movie_profile = pd.DataFrame(_movie_profile, columns=["movieId", "title", "profile", "weights"])
    movie_profile.set_index("movieId", inplace=True)
    return movie_profile

movie_profile = create_movie_profile(movies_dataset)

# %%
movie_profile.weights
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                                    profile  \
# movieId
# 1        [pixar, fun, Animation, Children, Fantasy, Adv...
# 2        [game, magic board game, Robin Williams, fanta...
# 3                            [moldy, old, Romance, Comedy]
# 4                                 [Comedy, Drama, Romance]
# 5                              [pregnancy, remake, Comedy]
#
#                                                    weights
# movieId
# 1        {'pixar': 0.837374709121301, 'fun': 0.34531665...
# 2        {'game': 0.49506005899914796, 'magic board gam...
# 3        {'moldy': 0.669101789463952, 'old': 0.66910178...
# 4            {'Comedy': 1.0, 'Drama': 1.0, 'Romance': 1.0}
# 5        {'pregnancy': 0.7029528753875794, 'remake': 0....

# %%
def create_inverted_table(movie_profile):
    inverted_table = {}
    for mid, weights in movie_profile['weights'].iteritems():
        for tag, weight in weights.items():
            # 到inverted_table dict 用tag作为key去取值， 如果取不到就返回[]
            _ = inverted_table.get(tag, [])
            _.append((mid, weight))
            inverted_table.setdefault(tag, _)
    return inverted_table

inverted_table = create_inverted_table(movie_profile)

# %%
import collections
from functools import reduce

def create_user_profile():
    watch_record = pd.read_csv("ml-latest-small/ratings.csv")
    train, test = train_test_split(watch_record, test_size=0.2, random_state=42)

    watch_record = train.iloc[:,:2].groupby("userId").agg(list)
    # print(watch_record)

    movie_dataset = get_movie_dataset()
    movie_profile = create_movie_profile(movie_dataset)

    user_profile = {}
    for uid, mids in watch_record.itertuples():
        record_movie_prifole = movie_profile.loc[list(mids)]
        counter = collections.Counter(reduce(lambda x, y: list(x)+list(y), record_movie_prifole["profile"].values))
        # 兴趣词
        interest_words = counter.most_common(50)
        maxcount = interest_words[0][1]
        interest_words = [(w,round(c/maxcount, 4)) for w,c in interest_words]
        user_profile[uid] = interest_words

    return user_profile, train, test

user_profile, train, test = create_user_profile()

# %%
user_profile
# Out:
# {1: [('Action', 1.0),
#   ('Adventure', 0.9444),
#   ('Comedy', 0.9222),
#   ('Drama', 0.7556),
#   ('Thriller', 0.6111),
#   ('Fantasy', 0.5222),
#   ('Crime', 0.5),
#   ('Children', 0.4667),
#   ('Sci-Fi', 0.4444),
#   ('Animation', 0.3222),
#   ('Romance', 0.2889),
#   ('War', 0.2444),
#   ('Musical', 0.2444),
#   ('Mystery', 0.2),
#   ('Horror', 0.1889),
#   ('Disney', 0.0889),
#   ('Western', 0.0778),
#   ('twist ending', 0.0556),
#   ('suspense', 0.0556),
#   ('superhero', 0.0556),
#   ('aliens', 0.0556),
#   ('sci-fi', 0.0444),
#   ('classic', 0.0444),
#   ('Vietnam', 0.0444),
#   ('disturbing', 0.0444),
#   ('psychology', 0.0444),
#   ('dark comedy', 0.0444),
#   ('great soundtrack', 0.0333),
#   ('space opera', 0.0333),
#   ('time travel', 0.0333),
#   ('thought-provoking', 0.0333),
#   ('King Arthur', 0.0333),
#   ('religion', 0.0333),
#   ('violence', 0.0333),
#   ('archaeology', 0.0333),
#   ('imdb top 250', 0.0333),
#   ('serial killer', 0.0222),
#   ('heist', 0.0222),
#   ('mindfuck', 0.0222),
#   ('off-beat comedy', 0.0222),
#   ('crime', 0.0222),
#   ('quirky', 0.0222),
#   ('revenge', 0.0222),
#   ('darth vader', 0.0222),
#   ('luke skywalker', 0.0222),
#   ('space', 0.0222),
#   ('action', 0.0222),
#   ('Tarantino', 0.0222),
#   ('hit men', 0.0222),
#   ('Quentin Tarantino', 0.0222)],
#  2: [('Drama', 1.0),
#   ('Action', 0.6471),
#   ('Crime', 0.5882),
#   ('Thriller', 0.5882),
#   ('Comedy', 0.4118),
#   ('Leonardo DiCaprio', 0.2941),
#   ('IMAX', 0.2353),
#   ('Sci-Fi', 0.2353),
#   ('Adventure', 0.1765),
#   ('suspense', 0.1765),
#   ('Martin Scorsese', 0.1765),
#   ('funny', 0.1765),
#   ('psychological', 0.1765),
#   ('thought-provoking', 0.1765),
#   ('Documentary', 0.1765),
#   ('visually appealing', 0.1765),
#   ('Morgan Freeman', 0.1176),
#   ('inspirational', 0.1176),
#   ('revenge', 0.1176),
#   ('psychology', 0.1176),
#   ('superhero', 0.1176),
#   ('Christoph Waltz', 0.1176),
#   ('Quentin Tarantino', 0.1176),
#   ('Mystery', 0.1176),
#   ('action', 0.1176),
#   ('sci-fi', 0.1176),
#   ('Christopher Nolan', 0.1176),
#   ('wrongful imprisonment', 0.0588),
#   ('prison', 0.0588),
#   ('Stephen King', 0.0588),
#   ('heartwarming', 0.0588),
#   ('Romance', 0.0588),
#   ('Epic', 0.0588),
#   ('Romans', 0.0588),
#   ('Russell Crowe', 0.0588),
#   ('ancient Rome', 0.0588),
#   ('history', 0.0588),
#   ('Rome', 0.0588),
#   ('imdb top 250', 0.0588),
#   ('martial arts', 0.0588),
#   ('Jack Nicholson', 0.0588),
#   ('undercover cop', 0.0588),
#   ('way too long', 0.0588),
#   ('twist ending', 0.0588),
#   ('atmospheric', 0.0588),
#   ('gritty', 0.0588),
#   ('dark', 0.0588),
#   ('will ferrell', 0.0588),
#   ('Highly quotable', 0.0588),
#   ('comedy', 0.0588)],
#  3: [('Drama', 1.0),
#   ('Sci-Fi', 0.9375),
#   ('Action', 0.875),
#   ('Adventure', 0.6875),
#   ('Comedy', 0.5625),
#   ('Horror', 0.5),
#   ('Thriller', 0.4375),
#   ('War', 0.3125),
#   ('Romance', 0.3125),
#   ('Children', 0.3125),
#   ('Animation', 0.25),
#   ('Fantasy', 0.25),
#   ('high school', 0.125),
#   ('Crime', 0.125),
#   ('teacher', 0.0625),
#   ('biography', 0.0625),
#   ('holocaust', 0.0625),
#   ('based on a true story', 0.0625),
#   ('moving', 0.0625),
#   ('Holocaust', 0.0625),
#   ('disturbing', 0.0625),
#   ('thought-provoking', 0.0625),
#   ('Gulf War', 0.0625),
#   ('Aardman', 0.0625),
#   ('George Bernard Shaw', 0.0625),
#   ('Musical', 0.0625),
#   ('1960s', 0.0625),
#   ('Jim Morrison', 0.0625),
#   ('music', 0.0625),
#   ('aging', 0.0625),
#   ('Vietnam', 0.0625),
#   ('World War II', 0.0625),
#   ('baseball', 0.0625),
#   ('Disney', 0.0625),
#   ('e-mail', 0.0625),
#   ('remake', 0.0625),
#   ('drug abuse', 0.0625),
#   ('depressing', 0.0625),
#   ('psychology', 0.0625),
#   ('Mystery', 0.0625),
#   ('immigrants', 0.0625)],
#  4: [('Drama', 1.0),
#   ('Comedy', 0.8667),
#   ('Romance', 0.4833),
#   ('Thriller', 0.3167),
#   ('Adventure', 0.2417),
#   ('Crime', 0.225),
#   ('Action', 0.2083),
#   ('Mystery', 0.1917),
#   ('Fantasy', 0.1583),
#   ('Musical', 0.1333),
#   ('Sci-Fi', 0.1),
#   ('Children', 0.0833),
#   ('Western', 0.0833),
#   ('War', 0.0583),
#   ('twist ending', 0.05),
#   ('In Netflix queue', 0.05),
#   ('Animation', 0.05),
#   ('Disney', 0.0417),
#   ('psychology', 0.0417),
#   ('imdb top 250', 0.0417),
#   ('music', 0.0417),
#   ('Horror', 0.0333),
#   ('Film-Noir', 0.0333),
#   ('mystery', 0.025),
#   ('Australia', 0.025),
#   ('sci-fi', 0.025),
#   ('classic', 0.025),
#   ('great soundtrack', 0.025),
#   ('drugs', 0.025),
#   ('based on a TV show', 0.025),
#   ('Coen Brothers', 0.025),
#   ('dark comedy', 0.025),
#   ('crime', 0.025),
#   ('Bruce Willis', 0.0167),
#   ('Brad Pitt', 0.0167),
#   ('mindfuck', 0.0167),
#   ('serial killer', 0.0167),
#   ('writing', 0.0167),
#   ('Documentary', 0.0167),
#   ('Ireland', 0.0167),
#   ('movie business', 0.0167),
#   ('space opera', 0.0167),
#   ('space', 0.0167),
#   ('hit men', 0.0167),
#   ('good dialogue', 0.0167),
#   ('cult film', 0.0167),
#   ('men in drag', 0.0167),
#   ('remade', 0.0167),
#   ('disturbing', 0.0167),
#   ('suspense', 0.0167)],
#  5: [('Drama', 1.0),
#   ('Comedy', 0.6),
#   ('Crime', 0.48),
#   ('Romance', 0.44),
#   ('Children', 0.36),
#   ('Thriller', 0.36),
#   ('Action', 0.36),
#   ('Adventure', 0.32),
#   ('Fantasy', 0.28),
#   ('Animation', 0.24),
#   ('Disney', 0.2),
#   ('Musical', 0.2),
#   ('War', 0.12),
#   ('IMAX', 0.12),
#   ('In Netflix queue', 0.12),
#   ('superhero', 0.08),
#   ('Western', 0.08),
#   ('time travel', 0.08),
#   ('Sci-Fi', 0.08),
#   ('dark comedy', 0.08),
#   ('based on a true story', 0.08),
#   ('pixar', 0.04),
#   ('fun', 0.04),
#   ('Hollywood', 0.04),
#   ('pigs', 0.04),
#   ('villain nonexistent or not needed for good story', 0.04),
#   ('Animal movie', 0.04),
#   ('Nun', 0.04),
#   ('death penalty', 0.04),
#   ('Emma', 0.04),
#   ('quotable', 0.04),
#   ('Paul Rudd', 0.04),
#   ('chick flick', 0.04),
#   ('seen more than once', 0.04),
#   ('Jane Austen', 0.04),
#   ('funny', 0.04),
#   ('tricky', 0.04),
#   ('thriller', 0.04),
#   ('heist', 0.04),
#   ('mindfuck', 0.04),
#   ('twist ending', 0.04),
#   ('suspense', 0.04),
#   ('Mystery', 0.04),
#   ('writing', 0.04),
#   ('Medieval', 0.04),
#   ('Oscar (Best Cinematography)', 0.04),
#   ('Scotland', 0.04),
#   ('historical', 0.04),
#   ('mel gibson', 0.04),
#   ('sword fight', 0.04)],
#  6: [('Drama', 1.0),
#   ('Comedy', 0.9071),
#   ('Romance', 0.5),
#   ('Thriller', 0.4857),
#   ('Action', 0.4571),
#   ('Children', 0.3357),
#   ('Adventure', 0.3357),
#   ('Crime', 0.25),
#   ('Fantasy', 0.1857),
#   ('Sci-Fi', 0.15),
#   ('Horror', 0.1357),
#   ('Mystery', 0.1071),
#   ('Animation', 0.1),
#   ('War', 0.0857),
#   ('Musical', 0.0857),
#   ('Western', 0.0786),
#   ('Disney', 0.0429),
#   ('twist ending', 0.0286),
#   ('remake', 0.0214),
#   ('Shakespeare', 0.0214),
#   ('time travel', 0.0214),
#   ('suspense', 0.0214),
#   ('IMAX', 0.0214),
#   ('Ireland', 0.0214),
#   ('psychology', 0.0214),
#   ('gothic', 0.0214),
#   ('dark comedy', 0.0214),
#   ('disturbing', 0.0214),
#   ('John Grisham', 0.0214),
#   ('politics', 0.0143),
#   ('Jane Austen', 0.0143),
#   ('serial killer', 0.0143),
#   ('alcoholism', 0.0143),
#   ('mindfuck', 0.0143),
#   ('Animal movie', 0.0143),
#   ('death penalty', 0.0143),
#   ('England', 0.0143),
#   ('wedding', 0.0143),
#   ('golf', 0.0143),
#   ('Adam Sandler', 0.0143),
#   ('journalism', 0.0143),
#   ('superhero', 0.0143),
#   ('mental illness', 0.0143),
#   ('Stephen King', 0.0143),
#   ('bad', 0.0143),
#   ('Christmas', 0.0143),
#   ('In Netflix queue', 0.0143),
#   ('hit men', 0.0143),
#   ('drama', 0.0143),
#   ('touching', 0.0143)],
#  7: [('Action', 1.0),
#   ('Drama', 0.8906),
#   ('Adventure', 0.8438),
#   ('Comedy', 0.7656),
#   ('Thriller', 0.6719),
#   ('Sci-Fi', 0.6562),
#   ('Romance', 0.4688),
#   ('Crime', 0.4062),
#   ('Fantasy', 0.3594),
#   ('Children', 0.2344),
#   ('Animation', 0.2188),
#   ('Mystery', 0.2188),
#   ('War', 0.1875),
#   ('IMAX', 0.1719),
#   ('Musical', 0.1406),
#   ('superhero', 0.1094),
#   ('space', 0.0938),
#   ('Horror', 0.0781),
#   ('mindfuck', 0.0625),
#   ('twist ending', 0.0625),
#   ('suspense', 0.0625),
#   ('space opera', 0.0625),
#   ('Disney', 0.0625),
#   ('robots', 0.0625),
#   ('Magic', 0.0625),
#   ('sci-fi', 0.0469),
#   ('time travel', 0.0469),
#   ('aliens', 0.0469),
#   ('artificial intelligence', 0.0469),
#   ('sequel', 0.0469),
#   ('imdb top 250', 0.0469),
#   ('Tom Hanks', 0.0469),
#   ('Wizards', 0.0469),
#   ('Tolkein', 0.0469),
#   ('heist', 0.0312),
#   ('classic', 0.0312),
#   ('darth vader', 0.0312),
#   ('luke skywalker', 0.0312),
#   ('great soundtrack', 0.0312),
#   ('action', 0.0312),
#   ('bittersweet', 0.0312),
#   ('Vietnam', 0.0312),
#   ('emotional', 0.0312),
#   ('overrated', 0.0312),
#   ('psychology', 0.0312),
#   ('future', 0.0312),
#   ('tense', 0.0312),
#   ('Film-Noir', 0.0312),
#   ('Atmospheric', 0.0312),
#   ('stylized', 0.0312)],
#  8: [('Comedy', 1.0),
#   ('Drama', 0.7917),
#   ('Thriller', 0.6667),
#   ('Romance', 0.5833),
#   ('Action', 0.5),
#   ('Adventure', 0.4583),
#   ('Crime', 0.375),
#   ('Children', 0.1667),
#   ('Fantasy', 0.1667),
#   ('Sci-Fi', 0.1667),
#   ('twist ending', 0.125),
#   ('Mystery', 0.125),
#   ('War', 0.125),
#   ('mindfuck', 0.0833),
#   ('suspense', 0.0833),
#   ('IMAX', 0.0833),
#   ('superhero', 0.0833),
#   ('Horror', 0.0833),
#   ('Western', 0.0833),
#   ('disturbing', 0.0833),
#   ('game', 0.0417),
#   ('magic board game', 0.0417),
#   ('Robin Williams', 0.0417),
#   ('fantasy', 0.0417),
#   ('president', 0.0417),
#   ('politics', 0.0417),
#   ('Hollywood', 0.0417),
#   ('time travel', 0.0417),
#   ('Bruce Willis', 0.0417),
#   ('Post apocalyptic', 0.0417),
#   ('Brad Pitt', 0.0417),
#   ('post-apocalyptic', 0.0417),
#   ('remake', 0.0417),
#   ('pigs', 0.0417),
#   ('villain nonexistent or not needed for good story', 0.0417),
#   ('Animal movie', 0.0417),
#   ('Emma', 0.0417),
#   ('quotable', 0.0417),
#   ('Paul Rudd', 0.0417),
#   ('chick flick', 0.0417),
#   ('seen more than once', 0.0417),
#   ('Jane Austen', 0.0417),
#   ('funny', 0.0417),
#   ('mystery', 0.0417),
#   ('serial killer', 0.0417),
#   ('tricky', 0.0417),
#   ('thriller', 0.0417),
#   ('heist', 0.0417),
#   ('Medieval', 0.0417),
#   ('Oscar (Best Cinematography)', 0.0417)],
#  9: [('Drama', 1.0),
#   ('Comedy', 0.7143),
#   ('Thriller', 0.5238),
#   ('Adventure', 0.4762),
#   ('Action', 0.381),
#   ('Sci-Fi', 0.381),
#   ('Crime', 0.3333),
#   ('Romance', 0.2857),
#   ('Horror', 0.2381),
#   ('Mystery', 0.1429),
#   ('War', 0.0952),
#   ('time travel', 0.0952),
#   ('Tolkein', 0.0952),
#   ('Fantasy', 0.0952),
#   ('Shakespeare', 0.0476),
#   ('independent film', 0.0476),
#   ('cynical', 0.0476),
#   ('hilarious', 0.0476),
#   ('generation X', 0.0476),
#   ('witty', 0.0476),
#   ('quirky', 0.0476),
#   ('journalism', 0.0476),
#   ('eerie', 0.0476),
#   ('movies', 0.0476),
#   ('movie business', 0.0476),
#   ('Film-Noir', 0.0476),
#   ('Rosebud', 0.0476),
#   ('indiana jones', 0.0476),
#   ('archaeology', 0.0476),
#   ('ark of the covenant', 0.0476),
#   ('Steven Spielberg', 0.0476),
#   ('treasure hunt', 0.0476),
#   ('adventure', 0.0476),
#   ('Amish', 0.0476),
#   ('Western', 0.0476),
#   ('Andy Garcia', 0.0476),
#   ('Classic', 0.0476),
#   ('Francis Ford Coppola', 0.0476),
#   ('mafia', 0.0476),
#   ('Al Pacino', 0.0476),
#   ('Broadway', 0.0476),
#   ('Musical', 0.0476),
#   ('police', 0.0476),
#   ('twins', 0.0476),
#   ('high fantasy', 0.0476),
#   ('mythology', 0.0476),
#   ('tolkien', 0.0476),
#   ('wizards', 0.0476),
#   ('Magic', 0.0476),
#   ('fantasy', 0.0476)],
#  10: [('Comedy', 1.0),
#   ('Romance', 0.9873),
#   ('Drama', 0.9114),
#   ('Adventure', 0.3924),
#   ('Action', 0.3291),
#   ('IMAX', 0.2278),
#   ('Fantasy', 0.2152),
#   ('Animation', 0.1899),
#   ('Children', 0.1772),
#   ('Crime', 0.1646),
#   ('Thriller', 0.1646),
#   ('Musical', 0.1139),
#   ('Sci-Fi', 0.0633),
#   ('War', 0.0506),
#   ('Disney', 0.0506),
#   ('emotional', 0.038),
#   ('sci-fi', 0.038),
#   ('Mystery', 0.038),
#   ('thought-provoking', 0.038),
#   ('Tolkein', 0.038),
#   ('fantasy', 0.038),
#   ('superhero', 0.038),
#   ('great soundtrack', 0.0253),
#   ('drugs', 0.0253),
#   ('touching', 0.0253),
#   ('heartwarming', 0.0253),
#   ('bittersweet', 0.0253),
#   ('music', 0.0253),
#   ('stylized', 0.0253),
#   ('imdb top 250', 0.0253),
#   ('twist ending', 0.0253),
#   ('Horror', 0.0253),
#   ('psychology', 0.0253),
#   ('politics', 0.0253),
#   ('Tolkien', 0.0253),
#   ('romance', 0.0253),
#   ('adventure', 0.0253),
#   ('too long', 0.0253),
#   ('Christopher Nolan', 0.0253),
#   ('cinematography', 0.0253),
#   ('non-linear', 0.0127),
#   ('Tarantino', 0.0127),
#   ('hit men', 0.0127),
#   ('good dialogue', 0.0127),
#   ('Quentin Tarantino', 0.0127),
#   ('cult film', 0.0127),
#   ('1990s', 0.0127),
#   ('AWESOME', 0.0127),
#   ('Black comedy', 0.0127),
#   ('Harvey Keitel', 0.0127)],
#  11: [('Action', 1.0),
#   ('Thriller', 0.6957),
#   ('Drama', 0.5217),
#   ('Adventure', 0.3913),
#   ('Crime', 0.2826),
#   ('Romance', 0.2826),
#   ('Comedy', 0.2609),
#   ('Sci-Fi', 0.2174),
#   ('War', 0.1304),
#   ('Mystery', 0.0652),
#   ('inspirational', 0.0435),
#   ('space', 0.0435),
#   ('heartwarming', 0.0435),
#   ('Western', 0.0435),
#   ('based on a TV show', 0.0435),
#   ('Nun', 0.0217),
#   ('death penalty', 0.0217),
#   ('Fantasy', 0.0217),
#   ('Medieval', 0.0217),
#   ('Oscar (Best Cinematography)', 0.0217),
#   ('Scotland', 0.0217),
#   ('historical', 0.0217),
#   ('mel gibson', 0.0217),
#   ('sword fight', 0.0217),
#   ('beautiful scenery', 0.0217),
#   ('epic', 0.0217),
#   ('revenge', 0.0217),
#   ('moon', 0.0217),
#   ('NASA', 0.0217),
#   ('IMAX', 0.0217),
#   ('superhero', 0.0217),
#   ('wrongful imprisonment', 0.0217),
#   ('Morgan Freeman', 0.0217),
#   ('prison', 0.0217),
#   ('Stephen King', 0.0217),
#   ('Tom Clancy', 0.0217),
#   ('bubba gump shrimp', 0.0217),
#   ('lieutenant dan', 0.0217),
#   ('shrimp', 0.0217),
#   ('stupid is as stupid does', 0.0217),
#   ('touching', 0.0217),
#   ('bittersweet', 0.0217),
#   ('Vietnam', 0.0217),
#   ('emotional', 0.0217),
#   ('bus', 0.0217),
#   ('spies', 0.0217),
#   ('assassination', 0.0217),
#   ('Dinosaur', 0.0217),
#   ('chess', 0.0217),
#   ('Scifi masterpiece', 0.0217)],
#  12: [('Romance', 1.0),
#   ('Comedy', 0.8571),
#   ('Drama', 0.7619),
#   ('Fantasy', 0.1905),
#   ('Sci-Fi', 0.1429),
#   ('Thriller', 0.1429),
#   ('chick flick', 0.0952),
#   ('Jane Austen', 0.0952),
#   ('Action', 0.0952),
#   ('Adventure', 0.0952),
#   ('romance', 0.0952),
#   ('Emma', 0.0476),
#   ('quotable', 0.0476),
#   ('Paul Rudd', 0.0476),
#   ('seen more than once', 0.0476),
#   ('funny', 0.0476),
#   ('Ireland', 0.0476),
#   ('Louisa May Alcott', 0.0476),
#   ('Christmas', 0.0476),
#   ('wedding', 0.0476),
#   ('beat poetry', 0.0476),
#   ('adultery', 0.0476),
#   ('Civil War', 0.0476),
#   ('War', 0.0476),
#   ('music', 0.0476),
#   ('Animation', 0.0476),
#   ('Crime', 0.0476),
#   ('shipwreck', 0.0476),
#   ('mermaid', 0.0476),
#   ('martial arts', 0.0476),
#   ('Shakespeare sort of', 0.0476),
#   ('high school', 0.0476),
#   ('Adam Sandler', 0.0476),
#   ('Ghosts', 0.0476),
#   ('ballet', 0.0476),
#   ('memory loss', 0.0476),
#   ('sad', 0.0476),
#   ('In Netflix queue', 0.0476),
#   ('Teen movie', 0.0476),
#   ('audience intelligence underestimated', 0.0476),
#   ('overrated', 0.0476),
#   ('boring', 0.0476)],
#  13: [('Drama', 1.0),
#   ('Thriller', 0.6875),
#   ('Comedy', 0.6875),
#   ('Action', 0.625),
#   ('Romance', 0.375),
#   ('Adventure', 0.375),
#   ('Horror', 0.3125),
#   ('Sci-Fi', 0.3125),
#   ('Crime', 0.1875),
#   ('Mystery', 0.125),
#   ('War', 0.125),
#   ('martial arts', 0.125),
#   ('mystery', 0.0625),
#   ('serial killer', 0.0625),
#   ('twist ending', 0.0625),
#   ('prostitution', 0.0625),
#   ('indiana jones', 0.0625),
#   ('archaeology', 0.0625),
#   ('ark of the covenant', 0.0625),
#   ('Steven Spielberg', 0.0625),
#   ('treasure hunt', 0.0625),
#   ('adventure', 0.0625),
#   ('shipwreck', 0.0625),
#   ('romance', 0.0625),
#   ('1980s', 0.0625),
#   ('high school', 0.0625),
#   ('Fantasy', 0.0625),
#   ('post apocalyptic', 0.0625),
#   ('alternate universe', 0.0625),
#   ('philosophy', 0.0625),
#   ('sci-fi', 0.0625),
#   ('Epic', 0.0625),
#   ('Romans', 0.0625),
#   ('Russell Crowe', 0.0625),
#   ('ancient Rome', 0.0625),
#   ('history', 0.0625),
#   ('Rome', 0.0625),
#   ('revenge', 0.0625),
#   ('imdb top 250', 0.0625),
#   ('Western', 0.0625),
#   ('superhero', 0.0625),
#   ('hugh jackman', 0.0625),
#   ('marvel', 0.0625),
#   ('comic book', 0.0625),
#   ('action', 0.0625),
#   ('music', 0.0625),
#   ('Rolling Stone', 0.0625),
#   ('journalism', 0.0625),
#   ('china', 0.0625)],
#  14: [('Drama', 1.0),
#   ('Comedy', 0.7083),
#   ('Romance', 0.5833),
#   ('Thriller', 0.5417),
#   ('Action', 0.5),
#   ('Adventure', 0.375),
#   ('Crime', 0.2917),
#   ('War', 0.1667),
#   ('Western', 0.1667),
#   ('remake', 0.0833),
#   ('twist ending', 0.0833),
#   ('Mystery', 0.0833),
#   ('Sci-Fi', 0.0833),
#   ('superhero', 0.0833),
#   ('Children', 0.0833),
#   ('disturbing', 0.0833),
#   ('alcoholism', 0.0417),
#   ('time travel', 0.0417),
#   ('Bruce Willis', 0.0417),
#   ('Post apocalyptic', 0.0417),
#   ('Brad Pitt', 0.0417),
#   ('post-apocalyptic', 0.0417),
#   ('mindfuck', 0.0417),
#   ('Emma', 0.0417),
#   ('quotable', 0.0417),
#   ('Paul Rudd', 0.0417),
#   ('chick flick', 0.0417),
#   ('seen more than once', 0.0417),
#   ('Jane Austen', 0.0417),
#   ('funny', 0.0417),
#   ('mystery', 0.0417),
#   ('serial killer', 0.0417),
#   ('Medieval', 0.0417),
#   ('Oscar (Best Cinematography)', 0.0417),
#   ('Scotland', 0.0417),
#   ('historical', 0.0417),
#   ('mel gibson', 0.0417),
#   ('sword fight', 0.0417),
#   ('beautiful scenery', 0.0417),
#   ('epic', 0.0417),
#   ('inspirational', 0.0417),
#   ('revenge', 0.0417),
#   ('moon', 0.0417),
#   ('NASA', 0.0417),
#   ('space', 0.0417),
#   ('IMAX', 0.0417),
#   ('twins', 0.0417),
#   ('disability', 0.0417),
#   ('brutality', 0.0417),
#   ('psychedelic', 0.0417)],
#  15: [('Action', 1.0),
#   ('Sci-Fi', 1.0),
#   ('Adventure', 0.9661),
#   ('Drama', 0.9153),
#   ('Thriller', 0.7458),
#   ('Comedy', 0.4746),
#   ('Animation', 0.3729),
#   ('Children', 0.3559),
#   ('Crime', 0.322),
#   ('IMAX', 0.3051),
#   ('Fantasy', 0.2712),
#   ('Romance', 0.2203),
#   ('Mystery', 0.2034),
#   ('Horror', 0.1864),
#   ('sci-fi', 0.1525),
#   ('thought-provoking', 0.1186),
#   ('Disney', 0.1017),
#   ('visually appealing', 0.1017),
#   ('action', 0.0847),
#   ('War', 0.0847),
#   ('Musical', 0.0847),
#   ('time travel', 0.0847),
#   ('psychology', 0.0847),
#   ('superhero', 0.0847),
#   ('twist ending', 0.0678),
#   ('space opera', 0.0678),
#   ('space', 0.0678),
#   ('tense', 0.0678),
#   ('suspense', 0.0678),
#   ('mindfuck', 0.0678),
#   ('great soundtrack', 0.0508),
#   ('humorous', 0.0508),
#   ('touching', 0.0508),
#   ('imdb top 250', 0.0508),
#   ('emotional', 0.0508),
#   ('robots', 0.0508),
#   ('aliens', 0.0508),
#   ('intelligent', 0.0508),
#   ('revenge', 0.0508),
#   ('Leonardo DiCaprio', 0.0508),
#   ('fun', 0.0339),
#   ('mystery', 0.0339),
#   ('classic', 0.0339),
#   ('darth vader', 0.0339),
#   ('luke skywalker', 0.0339),
#   ('hit men', 0.0339),
#   ('great acting', 0.0339),
#   ('love story', 0.0339),
#   ('unique', 0.0339),
#   ('disturbing', 0.0339)],
#  16: [('Drama', 1.0),
#   ('Thriller', 0.6042),
#   ('Action', 0.5208),
#   ('Comedy', 0.5208),
#   ('Crime', 0.5),
#   ('Adventure', 0.4167),
#   ('Sci-Fi', 0.3333),
#   ('Fantasy', 0.3333),
#   ('Mystery', 0.2708),
#   ('Romance', 0.2708),
#   ('Animation', 0.25),
#   ('War', 0.2292),
#   ('psychology', 0.1667),
#   ('Children', 0.1667),
#   ('thought-provoking', 0.1458),
#   ('twist ending', 0.1042),
#   ('mindfuck', 0.1042),
#   ('sci-fi', 0.1042),
#   ('emotional', 0.1042),
#   ('atmospheric', 0.1042),
#   ('dreamlike', 0.1042),
#   ('Horror', 0.1042),
#   ('Film-Noir', 0.1042),
#   ('surreal', 0.1042),
#   ('great soundtrack', 0.0833),
#   ('imdb top 250', 0.0833),
#   ('disturbing', 0.0833),
#   ('bittersweet', 0.0833),
#   ('Vietnam', 0.0833),
#   ('philosophy', 0.0833),
#   ('superhero', 0.0833),
#   ('anime', 0.0833),
#   ('IMAX', 0.0833),
#   ('mystery', 0.0625),
#   ('heist', 0.0625),
#   ('suspense', 0.0625),
#   ('assassination', 0.0625),
#   ('touching', 0.0625),
#   ('cult film', 0.0625),
#   ('dark comedy', 0.0625),
#   ('stylized', 0.0625),
#   ('mental illness', 0.0625),
#   ('adventure', 0.0625),
#   ('cerebral', 0.0625),
#   ('psychological', 0.0625),
#   ('Tolkein', 0.0625),
#   ('serial killer', 0.0417),
#   ('classic', 0.0417),
#   ('space opera', 0.0417),
#   ('space', 0.0417)],
#  17: [('Drama', 1.0),
#   ('Action', 0.7647),
#   ('Adventure', 0.6863),
#   ('Crime', 0.6275),
#   ('Thriller', 0.5294),
#   ('Sci-Fi', 0.3922),
#   ('Comedy', 0.3725),
#   ('Fantasy', 0.3333),
#   ('Animation', 0.1961),
#   ('Mystery', 0.1961),
#   ('War', 0.1765),
#   ('Children', 0.1373),
#   ('sci-fi', 0.1373),
#   ('Romance', 0.1373),
#   ('twist ending', 0.1176),
#   ('IMAX', 0.1176),
#   ('Western', 0.1176),
#   ('psychology', 0.1176),
#   ('suspense', 0.098),
#   ('great soundtrack', 0.098),
#   ('disturbing', 0.098),
#   ('atmospheric', 0.098),
#   ('time travel', 0.098),
#   ('mindfuck', 0.0784),
#   ('space', 0.0784),
#   ('imdb top 250', 0.0784),
#   ('Stephen King', 0.0784),
#   ('Vietnam', 0.0784),
#   ('thought-provoking', 0.0784),
#   ('Mafia', 0.0784),
#   ('violence', 0.0784),
#   ('anime', 0.0784),
#   ('mystery', 0.0588),
#   ('heist', 0.0588),
#   ('classic', 0.0588),
#   ('space opera', 0.0588),
#   ('Quentin Tarantino', 0.0588),
#   ('emotional', 0.0588),
#   ('robots', 0.0588),
#   ('dreamlike', 0.0588),
#   ('Horror', 0.0588),
#   ('dark comedy', 0.0588),
#   ('black comedy', 0.0588),
#   ('Musical', 0.0588),
#   ('stylized', 0.0588),
#   ('psychological', 0.0588),
#   ('Tolkein', 0.0588),
#   ('assassination', 0.0392),
#   ('darth vader', 0.0392),
#   ('luke skywalker', 0.0392)],
#  18: [('Drama', 1.0),
#   ('Action', 0.9633),
#   ('Thriller', 0.7752),
#   ('Comedy', 0.6789),
#   ('Adventure', 0.6514),
#   ('Crime', 0.633),
#   ('Sci-Fi', 0.5046),
#   ('Mystery', 0.2569),
#   ('Fantasy', 0.2385),
#   ('Romance', 0.2018),
#   ('IMAX', 0.1697),
#   ('Children', 0.1606),
#   ('Animation', 0.1422),
#   ('War', 0.0734),
#   ('Horror', 0.0688),
#   ('twist ending', 0.055),
#   ('Musical', 0.055),
#   ('thought-provoking', 0.055),
#   ('Western', 0.0505),
#   ('sci-fi', 0.0459),
#   ('psychology', 0.0459),
#   ('superhero', 0.0413),
#   ('Documentary', 0.0413),
#   ('mindfuck', 0.0367),
#   ('suspense', 0.0367),
#   ('Film-Noir', 0.0367),
#   ('time travel', 0.0321),
#   ('dark comedy', 0.0321),
#   ('imdb top 250', 0.0321),
#   ('emotional', 0.0321),
#   ('atmospheric', 0.0321),
#   ('Leonardo DiCaprio', 0.0321),
#   ('visually appealing', 0.0321),
#   ('Mafia', 0.0275),
#   ('heist', 0.0275),
#   ('stylized', 0.0275),
#   ('bittersweet', 0.0275),
#   ('black comedy', 0.0275),
#   ('comedy', 0.0275),
#   ('funny', 0.0275),
#   ('mystery', 0.0229),
#   ('inspirational', 0.0229),
#   ('quirky', 0.0229),
#   ('great soundtrack', 0.0229),
#   ('space', 0.0229),
#   ('humorous', 0.0229),
#   ('mental illness', 0.0229),
#   ('Disney', 0.0229),
#   ('future', 0.0229),
#   ('dreamlike', 0.0229)],
#  19: [('Comedy', 1.0),
#   ('Thriller', 0.537),
#   ('Adventure', 0.4153),
#   ('Drama', 0.3995),
#   ('Action', 0.3968),
#   ('Romance', 0.3545),
#   ('Sci-Fi', 0.336),
#   ('Horror', 0.2963),
#   ('Children', 0.2698),
#   ('Fantasy', 0.254),
#   ('Crime', 0.1905),
#   ('Mystery', 0.1534),
#   ('Animation', 0.127),
#   ('Musical', 0.0979),
#   ('Western', 0.0291),
#   ('War', 0.0238),
#   ('Film-Noir', 0.0238),
#   ('superhero', 0.0212),
#   ('time travel', 0.0185),
#   ('imdb top 250', 0.0185),
#   ('Disney', 0.0185),
#   ('spoof', 0.0185),
#   ('twist ending', 0.0159),
#   ('sci-fi', 0.0159),
#   ('remake', 0.0132),
#   ('mindfuck', 0.0132),
#   ('space', 0.0132),
#   ('tense', 0.0132),
#   ('high school', 0.0132),
#   ('space opera', 0.0106),
#   ('assassination', 0.0106),
#   ('dark comedy', 0.0106),
#   ('robots', 0.0106),
#   ('aliens', 0.0106),
#   ('sequel', 0.0106),
#   ('suspense', 0.0106),
#   ('Stephen King', 0.0106),
#   ('ghosts', 0.0106),
#   ('mystery', 0.0079),
#   ('serial killer', 0.0079),
#   ('Adam Sandler', 0.0079),
#   ('classic', 0.0079),
#   ('action', 0.0079),
#   ('disturbing', 0.0079),
#   ('based on a TV show', 0.0079),
#   ('atmospheric', 0.0079),
#   ('artificial intelligence', 0.0079),
#   ('future', 0.0079),
#   ('christmas', 0.0079),
#   ('Aardman', 0.0079)],
#  20: [('Children', 1.0),
#   ('Comedy', 0.9459),
#   ('Adventure', 0.7748),
#   ('Drama', 0.6396),
#   ('Animation', 0.5856),
#   ('Musical', 0.4955),
#   ('Fantasy', 0.4324),
#   ('Action', 0.4234),
#   ('Romance', 0.3604),
#   ('Thriller', 0.3333),
#   ('Crime', 0.2252),
#   ('Sci-Fi', 0.1982),
#   ('Disney', 0.1622),
#   ('Mystery', 0.1441),
#   ('Horror', 0.1081),
#   ('IMAX', 0.045),
#   ('War', 0.036),
#   ('superhero', 0.036),
#   ('Christmas', 0.027),
#   ('Tolkein', 0.027),
#   ('Magic', 0.027),
#   ('Robin Williams', 0.018),
#   ('fantasy', 0.018),
#   ('Animal movie', 0.018),
#   ('England', 0.018),
#   ('Aardman', 0.018),
#   ('race', 0.018),
#   ('twins', 0.018),
#   ('music', 0.018),
#   ('aliens', 0.018),
#   ('Pixar', 0.018),
#   ('Western', 0.018),
#   ('robots', 0.018),
#   ('animation', 0.018),
#   ('Tom Hanks', 0.018),
#   ('comedy', 0.018),
#   ('atmospheric', 0.018),
#   ('Documentary', 0.018),
#   ('Wizards', 0.018),
#   ('game', 0.009),
#   ('magic board game', 0.009),
#   ('pigs', 0.009),
#   ('villain nonexistent or not needed for good story', 0.009),
#   ('muppets', 0.009),
#   ('Girl Power', 0.009),
#   ('India', 0.009),
#   ('Disney animated feature', 0.009),
#   ('Oscar (Best Music - Original Score)', 0.009),
#   ('soundtrack', 0.009),
#   ('In Netflix queue', 0.009)],
#  21: [('Action', 1.0),
#   ('Comedy', 0.8894),
#   ('Adventure', 0.7832),
#   ('Thriller', 0.5398),
#   ('Sci-Fi', 0.469),
#   ('Drama', 0.4159),
#   ('Crime', 0.323),
#   ('Romance', 0.2876),
#   ('Fantasy', 0.2788),
#   ('Children', 0.2699),
#   ('Animation', 0.2566),
#   ('IMAX', 0.2522),
#   ('Mystery', 0.0796),
#   ('Musical', 0.0664),
#   ('Horror', 0.0664),
#   ('sci-fi', 0.0487),
#   ('superhero', 0.0398),
#   ('visually appealing', 0.0398),
#   ('action', 0.0354),
#   ('War', 0.0354),
#   ('funny', 0.0354),
#   ('robots', 0.0265),
#   ('sequel', 0.0221),
#   ('adventure', 0.0221),
#   ('thought-provoking', 0.0221),
#   ('Magic', 0.0221),
#   ('fantasy', 0.0177),
#   ('great soundtrack', 0.0177),
#   ('space opera', 0.0177),
#   ('space', 0.0177),
#   ('Disney', 0.0177),
#   ('time travel', 0.0177),
#   ('aliens', 0.0177),
#   ('Western', 0.0177),
#   ('surreal', 0.0177),
#   ('comic book', 0.0177),
#   ('comedy', 0.0177),
#   ('Wizards', 0.0177),
#   ('Leonardo DiCaprio', 0.0177),
#   ('cinematography', 0.0177),
#   ('fun', 0.0133),
#   ('classic', 0.0133),
#   ('humorous', 0.0133),
#   ('touching', 0.0133),
#   ('imdb top 250', 0.0133),
#   ('emotional', 0.0133),
#   ('atmospheric', 0.0133),
#   ('artificial intelligence', 0.0133),
#   ('mindfuck', 0.0133),
#   ('Aardman', 0.0133)],
#  22: [('Drama', 1.0),
#   ('Comedy', 0.5342),
#   ('Crime', 0.411),
#   ('Action', 0.411),
#   ('Thriller', 0.411),
#   ('Adventure', 0.3562),
#   ('Romance', 0.3014),
#   ('Fantasy', 0.2192),
#   ('Sci-Fi', 0.2055),
#   ('Children', 0.1644),
#   ('Animation', 0.1644),
#   ('Mystery', 0.1644),
#   ('atmospheric', 0.1096),
#   ('Horror', 0.0822),
#   ('War', 0.0822),
#   ('psychology', 0.0822),
#   ('IMAX', 0.0822),
#   ('bittersweet', 0.0685),
#   ('dreamlike', 0.0685),
#   ('thought-provoking', 0.0685),
#   ('surreal', 0.0685),
#   ('Documentary', 0.0685),
#   ('emotional', 0.0548),
#   ('quirky', 0.0548),
#   ('In Netflix queue', 0.0548),
#   ('sci-fi', 0.0411),
#   ('superhero', 0.0411),
#   ('twist ending', 0.0411),
#   ('Brad Pitt', 0.0411),
#   ('time travel', 0.0411),
#   ('revenge', 0.0411),
#   ('satire', 0.0411),
#   ('cerebral', 0.0411),
#   ('dark', 0.0411),
#   ('romance', 0.0411),
#   ('touching', 0.0274),
#   ('heartwarming', 0.0274),
#   ('future', 0.0274),
#   ('mindfuck', 0.0274),
#   ('mental illness', 0.0274),
#   ('police', 0.0274),
#   ('drugs', 0.0274),
#   ('creepy', 0.0274),
#   ('suspense', 0.0274),
#   ('dark comedy', 0.0274),
#   ('twist', 0.0274),
#   ('high school', 0.0274),
#   ('music', 0.0274),
#   ('Peter Pan', 0.0274),
#   ('martial arts', 0.0274)],
#  23: [('Drama', 1.0),
#   ('Crime', 0.5065),
#   ('Thriller', 0.4935),
#   ('Action', 0.3506),
#   ('Comedy', 0.3117),
#   ('Mystery', 0.2857),
#   ('Adventure', 0.2338),
#   ('Sci-Fi', 0.2208),
#   ('Fantasy', 0.1818),
#   ('Romance', 0.1558),
#   ('Film-Noir', 0.1429),
#   ('Animation', 0.1299),
#   ('War', 0.0779),
#   ('mindfuck', 0.0519),
#   ('heist', 0.0519),
#   ('atmospheric', 0.0519),
#   ('Mafia', 0.0519),
#   ('anime', 0.0519),
#   ('twist ending', 0.039),
#   ('suspense', 0.039),
#   ('hit men', 0.039),
#   ('robots', 0.039),
#   ('dark comedy', 0.039),
#   ('mystery', 0.039),
#   ('religion', 0.039),
#   ('Horror', 0.039),
#   ('samurai', 0.039),
#   ('revenge', 0.039),
#   ('Western', 0.039),
#   ('animation', 0.039),
#   ('Children', 0.039),
#   ('England', 0.026),
#   ('mental illness', 0.026),
#   ('humorous', 0.026),
#   ('imdb top 250', 0.026),
#   ('disturbing', 0.026),
#   ('Tarantino', 0.026),
#   ('good dialogue', 0.026),
#   ('Quentin Tarantino', 0.026),
#   ('cult film', 0.026),
#   ('Al Pacino', 0.026),
#   ('artificial intelligence', 0.026),
#   ('existentialism', 0.026),
#   ('future', 0.026),
#   ('philosophical', 0.026),
#   ('dreamlike', 0.026),
#   ('sci-fi', 0.026),
#   ('drug abuse', 0.026),
#   ('space', 0.026),
#   ('Stanley Kubrick', 0.026)],
#  24: [('Action', 1.0),
#   ('Comedy', 0.8929),
#   ('Drama', 0.7143),
#   ('Thriller', 0.6071),
#   ('Adventure', 0.5893),
#   ('Romance', 0.5893),
#   ('Sci-Fi', 0.4464),
#   ('Crime', 0.4107),
#   ('Fantasy', 0.2679),
#   ('Mystery', 0.2321),
#   ('IMAX', 0.1786),
#   ('War', 0.125),
#   ('Horror', 0.0714),
#   ('psychology', 0.0714),
#   ('surreal', 0.0714),
#   ('time travel', 0.0536),
#   ('remake', 0.0536),
#   ('mindfuck', 0.0536),
#   ('suspense', 0.0536),
#   ('future', 0.0536),
#   ('sci-fi', 0.0536),
#   ('Brad Pitt', 0.0357),
#   ('twist ending', 0.0357),
#   ('heist', 0.0357),
#   ('good dialogue', 0.0357),
#   ('great soundtrack', 0.0357),
#   ('Quentin Tarantino', 0.0357),
#   ('Morgan Freeman', 0.0357),
#   ('Stephen King', 0.0357),
#   ('heartwarming', 0.0357),
#   ('bittersweet', 0.0357),
#   ('disturbing', 0.0357),
#   ('aliens', 0.0357),
#   ('archaeology', 0.0357),
#   ('thought-provoking', 0.0357),
#   ('martial arts', 0.0357),
#   ('philosophy', 0.0357),
#   ('revenge', 0.0357),
#   ('hallucinatory', 0.0357),
#   ('Animation', 0.0357),
#   ('Children', 0.0357),
#   ('In Netflix queue', 0.0357),
#   ('clever', 0.0357),
#   ('black comedy', 0.0357),
#   ('superhero', 0.0357),
#   ('visually appealing', 0.0357),
#   ('cinematography', 0.0357),
#   ('Bruce Willis', 0.0179),
#   ('Post apocalyptic', 0.0179),
#   ('post-apocalyptic', 0.0179)],
#  25: [('Action', 1.0),
#   ('Adventure', 0.9333),
#   ('Drama', 0.8),
#   ('Sci-Fi', 0.6),
#   ('War', 0.2667),
#   ('Thriller', 0.2667),
#   ('Crime', 0.2667),
#   ('sci-fi', 0.2),
#   ('great soundtrack', 0.2),
#   ('thought-provoking', 0.2),
#   ('Tolkein', 0.2),
#   ('Fantasy', 0.2),
#   ('IMAX', 0.2),
#   ('Animation', 0.2),
#   ('Children', 0.2),
#   ('Comedy', 0.1333),
#   ('action', 0.1333),
#   ('adventure', 0.1333),
#   ('philosophy', 0.1333),
#   ('fantasy', 0.1333),
#   ('dark', 0.1333),
#   ('psychology', 0.1333),
#   ('superhero', 0.1333),
#   ('emotional', 0.1333),
#   ('Leonardo DiCaprio', 0.1333),
#   ('psychological', 0.1333),
#   ('Mystery', 0.1333),
#   ('dreamlike', 0.1333),
#   ('comic book', 0.1333),
#   ('classic sci-fi', 0.0667),
#   ('EPIC', 0.0667),
#   ('Star Wars', 0.0667),
#   ('space action', 0.0667),
#   ('classic', 0.0667),
#   ('Nerd', 0.0667),
#   ('ROBOTS AND ANDROIDS', 0.0667),
#   ('engrossing adventure', 0.0667),
#   ('oldie but goodie', 0.0667),
#   ('space adventure', 0.0667),
#   ('space epic', 0.0667),
#   ('darth vader', 0.0667),
#   ('luke skywalker', 0.0667),
#   ('space opera', 0.0667),
#   ('space', 0.0667),
#   ('biography', 0.0667),
#   ('holocaust', 0.0667),
#   ('based on a true story', 0.0667),
#   ('moving', 0.0667),
#   ('Holocaust', 0.0667),
#   ('disturbing', 0.0667)],
#  26: [('Thriller', 1.0),
#   ('Action', 0.7143),
#   ('Drama', 0.5714),
#   ('Crime', 0.5714),
#   ('Adventure', 0.4286),
#   ('Comedy', 0.3571),
#   ('superhero', 0.1429),
#   ('Romance', 0.1429),
#   ('pigs', 0.0714),
#   ('villain nonexistent or not needed for good story', 0.0714),
#   ('Animal movie', 0.0714),
#   ('Children', 0.0714),
#   ('mystery', 0.0714),
#   ('serial killer', 0.0714),
#   ('twist ending', 0.0714),
#   ('Mystery', 0.0714),
#   ('moon', 0.0714),
#   ('NASA', 0.0714),
#   ('space', 0.0714),
#   ('IMAX', 0.0714),
#   ('computers', 0.0714),
#   ('Sci-Fi', 0.0714),
#   ('brutality', 0.0714),
#   ('psychedelic', 0.0714),
#   ('controversial', 0.0714),
#   ('stylized', 0.0714),
#   ('satire', 0.0714),
#   ('dark comedy', 0.0714),
#   ('non-linear', 0.0714),
#   ('Tarantino', 0.0714),
#   ('hit men', 0.0714),
#   ('good dialogue', 0.0714),
#   ('great soundtrack', 0.0714),
#   ('Quentin Tarantino', 0.0714),
#   ('cult film', 0.0714),
#   ('drugs', 0.0714),
#   ('1990s', 0.0714),
#   ('AWESOME', 0.0714),
#   ('Black comedy', 0.0714),
#   ('Harvey Keitel', 0.0714),
#   ('John Travolta', 0.0714),
#   ("Palme d'Or", 0.0714),
#   ('Quotable', 0.0714),
#   ('Roger Avary', 0.0714),
#   ('Uma Thurman', 0.0714),
#   ('achronological', 0.0714),
#   ('action packed', 0.0714),
#   ('aggressive', 0.0714),
#   ('amazing', 0.0714),
#   ('amazing dialogues', 0.0714)],
#  27: [('Adventure', 1.0),
#   ('Comedy', 0.8475),
#   ('Children', 0.8305),
#   ('Drama', 0.7627),
#   ('Action', 0.7119),
#   ('Sci-Fi', 0.5424),
#   ('Romance', 0.3898),
#   ('Animation', 0.3729),
#   ('Fantasy', 0.3729),
#   ('War', 0.2542),
#   ('Thriller', 0.2373),
#   ('Musical', 0.2203),
#   ('Western', 0.1695),
#   ('Disney', 0.1356),
#   ('Crime', 0.1186),
#   ('space', 0.0678),
#   ('aliens', 0.0678),
#   ('sci-fi', 0.0508),
#   ('space opera', 0.0508),
#   ('Mystery', 0.0508),
#   ('Animal movie', 0.0339),
#   ('music', 0.0339),
#   ('classic', 0.0339),
#   ('darth vader', 0.0339),
#   ('luke skywalker', 0.0339),
#   ('action', 0.0339),
#   ('time travel', 0.0339),
#   ('Vietnam', 0.0339),
#   ('soundtrack', 0.0339),
#   ('IMAX', 0.0339),
#   ('Aardman', 0.0339),
#   ('sequel', 0.0339),
#   ('archaeology', 0.0339),
#   ('Horror', 0.0339),
#   ('racism', 0.0339),
#   ('POW', 0.0339),
#   ('Pixar', 0.0339),
#   ('pixar', 0.0169),
#   ('fun', 0.0169),
#   ('game', 0.0169),
#   ('magic board game', 0.0169),
#   ('Robin Williams', 0.0169),
#   ('fantasy', 0.0169),
#   ('pigs', 0.0169),
#   ('villain nonexistent or not needed for good story', 0.0169),
#   ('classic sci-fi', 0.0169),
#   ('EPIC', 0.0169),
#   ('Star Wars', 0.0169),
#   ('space action', 0.0169),
#   ('Nerd', 0.0169)],
#  28: [('Drama', 1.0),
#   ('Thriller', 0.5686),
#   ('Action', 0.549),
#   ('Crime', 0.4202),
#   ('Sci-Fi', 0.3445),
#   ('Adventure', 0.3333),
#   ('Comedy', 0.2689),
#   ('Mystery', 0.1569),
#   ('War', 0.1429),
#   ('Romance', 0.1148),
#   ('Fantasy', 0.084),
#   ('Horror', 0.0756),
#   ('Western', 0.0672),
#   ('IMAX', 0.0364),
#   ('twist ending', 0.0308),
#   ('sci-fi', 0.028),
#   ('psychology', 0.0252),
#   ('In Netflix queue', 0.0252),
#   ('time travel', 0.0224),
#   ('mindfuck', 0.0224),
#   ('atmospheric', 0.0224),
#   ('superhero', 0.0224),
#   ('thought-provoking', 0.0196),
#   ('aliens', 0.0196),
#   ('Mafia', 0.0168),
#   ('suspense', 0.0168),
#   ('space', 0.0168),
#   ('robots', 0.0168),
#   ('dark comedy', 0.0168),
#   ('Film-Noir', 0.0168),
#   ('revenge', 0.014),
#   ('cult film', 0.014),
#   ('drugs', 0.014),
#   ('artificial intelligence', 0.014),
#   ('future', 0.014),
#   ('Coen Brothers', 0.014),
#   ('Musical', 0.014),
#   ('politics', 0.014),
#   ('martial arts', 0.014),
#   ('Animation', 0.014),
#   ('Brad Pitt', 0.0112),
#   ('Leonardo DiCaprio', 0.0112),
#   ('mental illness', 0.0112),
#   ('great soundtrack', 0.0112),
#   ('space opera', 0.0112),
#   ('tense', 0.0112),
#   ('imdb top 250', 0.0112),
#   ('disturbing', 0.0112),
#   ('emotional', 0.0112),
#   ('dreamlike', 0.0112)],
#  29: [('Drama', 1.0),
#   ('Action', 0.62),
#   ('War', 0.44),
#   ('Thriller', 0.42),
#   ('Adventure', 0.42),
#   ('Sci-Fi', 0.36),
#   ('Crime', 0.3),
#   ('Comedy', 0.22),
#   ('Western', 0.18),
#   ('Mystery', 0.14),
#   ('Romance', 0.12),
#   ('IMAX', 0.1),
#   ('Vietnam', 0.08),
#   ('Fantasy', 0.08),
#   ('time travel', 0.06),
#   ('Musical', 0.06),
#   ('World War II', 0.06),
#   ('twist ending', 0.04),
#   ('suspense', 0.04),
#   ('space', 0.04),
#   ('Quentin Tarantino', 0.04),
#   ('cult film', 0.04),
#   ('Mafia', 0.04),
#   ('mystery', 0.04),
#   ('imdb top 250', 0.04),
#   ('robots', 0.04),
#   ('Children', 0.04),
#   ('King Arthur', 0.04),
#   ('England', 0.04),
#   ('spaghetti western', 0.04),
#   ('POW', 0.04),
#   ('Horror', 0.04),
#   ('Documentary', 0.04),
#   ('Leonardo DiCaprio', 0.04),
#   ('atmospheric', 0.04),
#   ('predictable', 0.04),
#   ('tricky', 0.02),
#   ('thriller', 0.02),
#   ('heist', 0.02),
#   ('mindfuck', 0.02),
#   ('moon', 0.02),
#   ('NASA', 0.02),
#   ('non-linear', 0.02),
#   ('Tarantino', 0.02),
#   ('hit men', 0.02),
#   ('good dialogue', 0.02),
#   ('great soundtrack', 0.02),
#   ('drugs', 0.02),
#   ('1990s', 0.02),
#   ('AWESOME', 0.02)],
#  30: [('Action', 1.0),
#   ('Adventure', 0.76),
#   ('Sci-Fi', 0.68),
#   ('sci-fi', 0.32),
#   ('IMAX', 0.32),
#   ('Drama', 0.28),
#   ('Crime', 0.28),
#   ('Thriller', 0.2),
#   ('Animation', 0.2),
#   ('Comedy', 0.2),
#   ('space', 0.16),
#   ('Fantasy', 0.16),
#   ('great soundtrack', 0.12),
#   ('space opera', 0.12),
#   ('action', 0.12),
#   ('robots', 0.12),
#   ('time travel', 0.12),
#   ('Tolkein', 0.12),
#   ('Children', 0.12),
#   ('classic', 0.08),
#   ('darth vader', 0.08),
#   ('luke skywalker', 0.08),
#   ('Morgan Freeman', 0.08),
#   ('archaeology', 0.08),
#   ('adventure', 0.08),
#   ('suspense', 0.08),
#   ('philosophy', 0.08),
#   ('fantasy', 0.08),
#   ('psychology', 0.08),
#   ('superhero', 0.08),
#   ('Romance', 0.08),
#   ('thought-provoking', 0.08),
#   ('visually appealing', 0.08),
#   ('clever', 0.08),
#   ('Christopher Nolan', 0.08),
#   ('feel-good', 0.08),
#   ('Medieval', 0.04),
#   ('Oscar (Best Cinematography)', 0.04),
#   ('Scotland', 0.04),
#   ('historical', 0.04),
#   ('mel gibson', 0.04),
#   ('sword fight', 0.04),
#   ('beautiful scenery', 0.04),
#   ('epic', 0.04),
#   ('inspirational', 0.04),
#   ('revenge', 0.04),
#   ('War', 0.04),
#   ('classic sci-fi', 0.04),
#   ('EPIC', 0.04),
#   ('Star Wars', 0.04)],
#  31: [('Comedy', 1.0),
#   ('Romance', 0.7273),
#   ('Adventure', 0.6818),
#   ('Action', 0.6818),
#   ('Drama', 0.6818),
#   ('Thriller', 0.5),
#   ('Fantasy', 0.4545),
#   ('Sci-Fi', 0.4091),
#   ('Children', 0.3182),
#   ('Animation', 0.2273),
#   ('Musical', 0.2273),
#   ('Crime', 0.1364),
#   ('aliens', 0.1364),
#   ('space', 0.1364),
#   ('remake', 0.0909),
#   ('music', 0.0909),
#   ('Disney', 0.0909),
#   ('sci-fi', 0.0909),
#   ('Horror', 0.0909),
#   ('time travel', 0.0909),
#   ('pixar', 0.0455),
#   ('fun', 0.0455),
#   ('pregnancy', 0.0455),
#   ('Jane Austen', 0.0455),
#   ('alcoholism', 0.0455),
#   ('coma', 0.0455),
#   ('bus', 0.0455),
#   ('based on a TV show', 0.0455),
#   ('Mystery', 0.0455),
#   ('Alcatraz', 0.0455),
#   ('Michael Bay', 0.0455),
#   ('terrorism', 0.0455),
#   ('Disaster', 0.0455),
#   ('golf', 0.0455),
#   ('start of a beautiful friendship', 0.0455),
#   ('Monty Python', 0.0455),
#   ('british comedy', 0.0455),
#   ('King Arthur', 0.0455),
#   ('England', 0.0455),
#   ('George Lucas', 0.0455),
#   ('Harrison Ford', 0.0455),
#   ('I am your father', 0.0455),
#   ('original plot', 0.0455),
#   ('space opera', 0.0455),
#   ('sequel', 0.0455),
#   ('classic', 0.0455),
#   ('Inigo Montoya', 0.0455),
#   ('six-fingered man', 0.0455),
#   ('indiana jones', 0.0455),
#   ('archaeology', 0.0455)],
#  32: [('Drama', 1.0),
#   ('Comedy', 0.9773),
#   ('Thriller', 0.75),
#   ('Romance', 0.6818),
#   ('Action', 0.6818),
#   ('Crime', 0.4318),
#   ('Adventure', 0.4091),
#   ('Fantasy', 0.2727),
#   ('Sci-Fi', 0.25),
#   ('Mystery', 0.1818),
#   ('Children', 0.1364),
#   ('remake', 0.0682),
#   ('Shakespeare', 0.0682),
#   ('twist ending', 0.0682),
#   ('suspense', 0.0682),
#   ('mental illness', 0.0682),
#   ('psychology', 0.0682),
#   ('War', 0.0682),
#   ('Horror', 0.0682),
#   ('Animation', 0.0455),
#   ('mindfuck', 0.0455),
#   ('music', 0.0455),
#   ('superhero', 0.0455),
#   ('sci-fi', 0.0455),
#   ('classic', 0.0455),
#   ('great soundtrack', 0.0455),
#   ('space opera', 0.0455),
#   ('space', 0.0455),
#   ('gothic', 0.0455),
#   ('dark comedy', 0.0455),
#   ('based on a true story', 0.0455),
#   ('disturbing', 0.0455),
#   ('thought-provoking', 0.0455),
#   ('Musical', 0.0455),
#   ('pixar', 0.0227),
#   ('fun', 0.0227),
#   ('moldy', 0.0227),
#   ('old', 0.0227),
#   ('Hollywood', 0.0227),
#   ('alcoholism', 0.0227),
#   ('time travel', 0.0227),
#   ('Bruce Willis', 0.0227),
#   ('Post apocalyptic', 0.0227),
#   ('Brad Pitt', 0.0227),
#   ('post-apocalyptic', 0.0227),
#   ('Nun', 0.0227),
#   ('death penalty', 0.0227),
#   ('Emma', 0.0227),
#   ('quotable', 0.0227),
#   ('Paul Rudd', 0.0227)],
#  33: [('Drama', 1.0),
#   ('Comedy', 0.5043),
#   ('Romance', 0.4783),
#   ('Thriller', 0.2609),
#   ('Crime', 0.2261),
#   ('Action', 0.1217),
#   ('Adventure', 0.087),
#   ('Mystery', 0.0783),
#   ('Children', 0.0696),
#   ('War', 0.0696),
#   ('In Netflix queue', 0.0609),
#   ('Sci-Fi', 0.0609),
#   ('Animation', 0.0522),
#   ('Fantasy', 0.0522),
#   ('Musical', 0.0522),
#   ('England', 0.0435),
#   ('Jane Austen', 0.0348),
#   ('hit men', 0.0348),
#   ('mindfuck', 0.0261),
#   ('twist ending', 0.0261),
#   ('disturbing', 0.0261),
#   ('remake', 0.0174),
#   ('time travel', 0.0174),
#   ('Bruce Willis', 0.0174),
#   ('seen more than once', 0.0174),
#   ('heist', 0.0174),
#   ('suspense', 0.0174),
#   ('inspirational', 0.0174),
#   ('cynical', 0.0174),
#   ('Stephen King', 0.0174),
#   ('mental illness', 0.0174),
#   ('drama', 0.0174),
#   ('touching', 0.0174),
#   ('police', 0.0174),
#   ('imdb top 250', 0.0174),
#   ('TV', 0.0174),
#   ('heartwarming', 0.0174),
#   ('bittersweet', 0.0174),
#   ('Vietnam', 0.0174),
#   ('emotional', 0.0174),
#   ('Shakespeare', 0.0174),
#   ('based on a true story', 0.0174),
#   ('Holocaust', 0.0174),
#   ('thought-provoking', 0.0174),
#   ('adolescence', 0.0174),
#   ('Disney', 0.0174),
#   ('sci-fi', 0.0174),
#   ('Horror', 0.0174),
#   ('dark comedy', 0.0174),
#   ('Mafia', 0.0174)],
#  34: [('Action', 1.0),
#   ('Comedy', 0.7255),
#   ('Adventure', 0.5098),
#   ('Thriller', 0.5098),
#   ('Drama', 0.4706),
#   ('Sci-Fi', 0.451),
#   ('Romance', 0.3922),
#   ('Fantasy', 0.2745),
#   ('Crime', 0.2157),
#   ('Horror', 0.1765),
#   ('Mystery', 0.1373),
#   ('Animation', 0.1373),
#   ('War', 0.098),
#   ('martial arts', 0.0784),
#   ('revenge', 0.0588),
#   ('sci-fi', 0.0588),
#   ('aliens', 0.0588),
#   ('sequel', 0.0588),
#   ('twist ending', 0.0588),
#   ('superhero', 0.0588),
#   ('IMAX', 0.0588),
#   ('Western', 0.0392),
#   ('bittersweet', 0.0392),
#   ('emotional', 0.0392),
#   ('mindfuck', 0.0392),
#   ('Children', 0.0392),
#   ('psychology', 0.0392),
#   ('atmospheric', 0.0392),
#   ('clever', 0.0392),
#   ('Medieval', 0.0196),
#   ('Oscar (Best Cinematography)', 0.0196),
#   ('Scotland', 0.0196),
#   ('historical', 0.0196),
#   ('mel gibson', 0.0196),
#   ('sword fight', 0.0196),
#   ('beautiful scenery', 0.0196),
#   ('epic', 0.0196),
#   ('inspirational', 0.0196),
#   ('wrongful imprisonment', 0.0196),
#   ('Morgan Freeman', 0.0196),
#   ('prison', 0.0196),
#   ('Stephen King', 0.0196),
#   ('bubba gump shrimp', 0.0196),
#   ('lieutenant dan', 0.0196),
#   ('shrimp', 0.0196),
#   ('stupid is as stupid does', 0.0196),
#   ('touching', 0.0196),
#   ('heartwarming', 0.0196),
#   ('Vietnam', 0.0196),
#   ('wedding', 0.0196)],
#  35: [('Comedy', 1.0),
#   ('Romance', 0.9),
#   ('Drama', 0.9),
#   ('Adventure', 0.5),
#   ('Crime', 0.4),
#   ('Thriller', 0.4),
#   ('Action', 0.4),
#   ('Children', 0.2),
#   ('Fantasy', 0.2),
#   ('IMAX', 0.2),
#   ('Western', 0.2),
#   ('president', 0.1),
#   ('politics', 0.1),
#   ('Hollywood', 0.1),
#   ('Emma', 0.1),
#   ('quotable', 0.1),
#   ('Paul Rudd', 0.1),
#   ('chick flick', 0.1),
#   ('seen more than once', 0.1),
#   ('Jane Austen', 0.1),
#   ('funny', 0.1),
#   ('tricky', 0.1),
#   ('thriller', 0.1),
#   ('heist', 0.1),
#   ('mindfuck', 0.1),
#   ('twist ending', 0.1),
#   ('suspense', 0.1),
#   ('Mystery', 0.1),
#   ('music', 0.1),
#   ('moon', 0.1),
#   ('NASA', 0.1),
#   ('space', 0.1),
#   ('computers', 0.1),
#   ('Ireland', 0.1),
#   ('movie business', 0.1),
#   ('infertility', 0.1),
#   ('France', 0.1),
#   ('basketball', 0.1),
#   ('Einstein', 0.1),
#   ('Louisa May Alcott', 0.1),
#   ('War', 0.1),
#   ('TV', 0.1),
#   ('time travel', 0.1),
#   ('Sci-Fi', 0.1),
#   ('coma', 0.1),
#   ('weddings', 0.1),
#   ('Australia', 0.1),
#   ('American Indians', 0.1),
#   ('Native Americans', 0.1),
#   ('superhero', 0.1)],
#  36: [('Drama', 1.0),
#   ('Comedy', 0.8519),
#   ('Action', 0.6667),
#   ('Crime', 0.6296),
#   ('Thriller', 0.5185),
#   ('Romance', 0.4815),
#   ('Adventure', 0.4815),
#   ('Mystery', 0.3704),
#   ('War', 0.1852),
#   ('Sci-Fi', 0.1852),
#   ('Children', 0.1111),
#   ('Fantasy', 0.1111),
#   ('imdb top 250', 0.0741),
#   ('Vietnam', 0.0741),
#   ('Film-Noir', 0.0741),
#   ('alcoholism', 0.037),
#   ('wrongful imprisonment', 0.037),
#   ('Morgan Freeman', 0.037),
#   ('prison', 0.037),
#   ('Stephen King', 0.037),
#   ('knights', 0.037),
#   ('photographer', 0.037),
#   ('voyeurism', 0.037),
#   ('James Stewart', 0.037),
#   ('photography', 0.037),
#   ('mystery', 0.037),
#   ('Mount Rushmore', 0.037),
#   ('Alfred Hitchcock', 0.037),
#   ('Dorothy', 0.037),
#   ('Toto', 0.037),
#   ('Musical', 0.037),
#   ('anti-war', 0.037),
#   ('The Entertainer', 0.037),
#   ('incest', 0.037),
#   ('POW', 0.037),
#   ('spoof', 0.037),
#   ('ex-con', 0.037),
#   ('Klingons', 0.037),
#   ('whales', 0.037),
#   ('spying', 0.037),
#   ('lawyer', 0.037),
#   ('reunion', 0.037),
#   ('hit men', 0.037),
#   ('Police', 0.037),
#   ('inspirational', 0.037),
#   ('heartwarming', 0.037),
#   ('Western', 0.037),
#   ('Capone', 0.037),
#   ('gangsters', 0.037),
#   ('court', 0.037)],
#  37: [('Thriller', 1.0),
#   ('Adventure', 0.8889),
#   ('Drama', 0.8889),
#   ('Comedy', 0.8889),
#   ('Crime', 0.7778),
#   ('Action', 0.7778),
#   ('Sci-Fi', 0.4444),
#   ('superhero', 0.2222),
#   ('Romance', 0.2222),
#   ('Children', 0.2222),
#   ('Fantasy', 0.2222),
#   ('Musical', 0.2222),
#   ('moon', 0.1111),
#   ('NASA', 0.1111),
#   ('space', 0.1111),
#   ('IMAX', 0.1111),
#   ('non-linear', 0.1111),
#   ('Tarantino', 0.1111),
#   ('hit men', 0.1111),
#   ('good dialogue', 0.1111),
#   ('great soundtrack', 0.1111),
#   ('Quentin Tarantino', 0.1111),
#   ('cult film', 0.1111),
#   ('drugs', 0.1111),
#   ('1990s', 0.1111),
#   ('AWESOME', 0.1111),
#   ('Black comedy', 0.1111),
#   ('Harvey Keitel', 0.1111),
#   ('John Travolta', 0.1111),
#   ("Palme d'Or", 0.1111),
#   ('Quotable', 0.1111),
#   ('Roger Avary', 0.1111),
#   ('Uma Thurman', 0.1111),
#   ('achronological', 0.1111),
#   ('action packed', 0.1111),
#   ('aggressive', 0.1111),
#   ('amazing', 0.1111),
#   ('amazing dialogues', 0.1111),
#   ('anthology', 0.1111),
#   ('bad ass', 0.1111),
#   ('bad language', 0.1111),
#   ('bad-ass', 0.1111),
#   ('bible', 0.1111),
#   ('biblical references', 0.1111),
#   ('big boys with guns', 0.1111),
#   ('big name actors', 0.1111),
#   ('time travel', 0.1111),
#   ('wrongful imprisonment', 0.1111),
#   ('Morgan Freeman', 0.1111),
#   ('prison', 0.1111)],
#  38: [('Comedy', 1.0),
#   ('Drama', 1.0),
#   ('Romance', 0.7714),
#   ('Action', 0.5429),
#   ('Thriller', 0.5143),
#   ('Adventure', 0.4571),
#   ('Crime', 0.2571),
#   ('Children', 0.2286),
#   ('War', 0.2),
#   ('Fantasy', 0.2),
#   ('Sci-Fi', 0.1714),
#   ('Animation', 0.1429),
#   ('Musical', 0.1429),
#   ('Western', 0.1429),
#   ('Mystery', 0.0857),
#   ('IMAX', 0.0857),
#   ('Horror', 0.0857),
#   ('gothic', 0.0857),
#   ('Disney', 0.0857),
#   ('Jane Austen', 0.0571),
#   ('suspense', 0.0571),
#   ('superhero', 0.0571),
#   ('mental illness', 0.0571),
#   ('psychology', 0.0571),
#   ('basketball', 0.0571),
#   ('Christmas', 0.0571),
#   ('John Grisham', 0.0571),
#   ('based on a TV show', 0.0571),
#   ('disturbing', 0.0571),
#   ('president', 0.0286),
#   ('politics', 0.0286),
#   ('Hollywood', 0.0286),
#   ('Emma', 0.0286),
#   ('quotable', 0.0286),
#   ('Paul Rudd', 0.0286),
#   ('chick flick', 0.0286),
#   ('seen more than once', 0.0286),
#   ('funny', 0.0286),
#   ('tricky', 0.0286),
#   ('thriller', 0.0286),
#   ('heist', 0.0286),
#   ('mindfuck', 0.0286),
#   ('twist ending', 0.0286),
#   ('music', 0.0286),
#   ('Medieval', 0.0286),
#   ('Oscar (Best Cinematography)', 0.0286),
#   ('Scotland', 0.0286),
#   ('historical', 0.0286),
#   ('mel gibson', 0.0286),
#   ('sword fight', 0.0286)],
#  39: [('Drama', 1.0),
#   ('Adventure', 0.9143),
#   ('Action', 0.8),
#   ('Comedy', 0.8),
#   ('Crime', 0.7143),
#   ('Animation', 0.6857),
#   ('Thriller', 0.6571),
#   ('Children', 0.6571),
#   ('Sci-Fi', 0.6),
#   ('Musical', 0.4571),
#   ('Fantasy', 0.4571),
#   ('Horror', 0.3714),
#   ('Disney', 0.3429),
#   ('Romance', 0.2857),
#   ('Mystery', 0.2286),
#   ('twist ending', 0.1429),
#   ('sci-fi', 0.1429),
#   ('mindfuck', 0.1143),
#   ('suspense', 0.1143),
#   ('space', 0.1143),
#   ('time travel', 0.0857),
#   ('heist', 0.0857),
#   ('space opera', 0.0857),
#   ('action', 0.0857),
#   ('Mafia', 0.0857),
#   ('imdb top 250', 0.0857),
#   ('aliens', 0.0857),
#   ('atmospheric', 0.0857),
#   ('Bruce Willis', 0.0571),
#   ('mystery', 0.0571),
#   ('classic', 0.0571),
#   ('darth vader', 0.0571),
#   ('luke skywalker', 0.0571),
#   ('great soundtrack', 0.0571),
#   ('Tarantino', 0.0571),
#   ('hit men', 0.0571),
#   ('Quentin Tarantino', 0.0571),
#   ('cult film', 0.0571),
#   ('soundtrack', 0.0571),
#   ('robots', 0.0571),
#   ('superhero', 0.0571),
#   ('disturbing', 0.0571),
#   ('psychology', 0.0571),
#   ('Coen Brothers', 0.0571),
#   ('Alfred Hitchcock', 0.0571),
#   ('Stanley Kubrick', 0.0571),
#   ('masterpiece', 0.0571),
#   ('King Arthur', 0.0571),
#   ('stylized', 0.0571),
#   ('music', 0.0571)],
#  40: [('Drama', 1.0),
#   ('Comedy', 0.82),
#   ('Adventure', 0.46),
#   ('Action', 0.46),
#   ('Romance', 0.44),
#   ('Children', 0.36),
#   ('Thriller', 0.3),
#   ('Crime', 0.26),
#   ('Fantasy', 0.24),
#   ('Sci-Fi', 0.22),
#   ('Animation', 0.16),
#   ('Musical', 0.14),
#   ('Western', 0.12),
#   ('Disney', 0.08),
#   ('War', 0.06),
#   ('IMAX', 0.06),
#   ('Mystery', 0.06),
#   ('mental illness', 0.06),
#   ('Horror', 0.06),
#   ('Adam Sandler', 0.04),
#   ('superhero', 0.04),
#   ('cynical', 0.04),
#   ('Stephen King', 0.04),
#   ('gothic', 0.04),
#   ('Christmas', 0.04),
#   ('John Grisham', 0.04),
#   ('pixar', 0.02),
#   ('fun', 0.02),
#   ('Jane Austen', 0.02),
# ...
#   ('Stephen King', 0.0143),
#   ('president', 0.0095),
#   ('Jane Austen', 0.0095)],
#  598: [('Romance', 1.0),
#   ('Comedy', 0.8182),
#   ('Adventure', 0.7273),
#   ('Drama', 0.7273),
#   ('Thriller', 0.5455),
#   ('Action', 0.4545),
#   ('Crime', 0.3636),
#   ('Fantasy', 0.3636),
#   ('Sci-Fi', 0.3636),
#   ('psychology', 0.2727),
#   ('dreamlike', 0.2727),
#   ('Mystery', 0.2727),
#   ('suspense', 0.1818),
#   ('cerebral', 0.1818),
#   ('psychological', 0.1818),
#   ('Animation', 0.1818),
#   ('Children', 0.1818),
#   ('heist', 0.1818),
#   ('thought-provoking', 0.1818),
#   ('surreal', 0.1818),
#   ('alternate reality', 0.1818),
#   ('philosophy', 0.1818),
#   ('IMAX', 0.1818),
#   ('Hannibal Lector', 0.0909),
#   ('drama', 0.0909),
#   ('gothic', 0.0909),
#   ('disturbing', 0.0909),
#   ('Horror', 0.0909),
#   ('Inigo Montoya', 0.0909),
#   ('six-fingered man', 0.0909),
#   ('twist ending', 0.0909),
#   ('mystery', 0.0909),
#   ('Backwards. memory', 0.0909),
#   ('Mindfuck', 0.0909),
#   ('nonlinear', 0.0909),
#   ('dark', 0.0909),
#   ('fairy tales', 0.0909),
#   ('Wizards', 0.0909),
#   ('Magic', 0.0909),
#   ('memory', 0.0909),
#   ('arthouse', 0.0909),
#   ('colourful', 0.0909),
#   ('happpiness', 0.0909),
#   ('humane', 0.0909),
#   ('insightful', 0.0909),
#   ('jim carrey', 0.0909),
#   ('lovely', 0.0909),
#   ('mind-bending', 0.0909),
#   ('quirky romantic', 0.0909),
#   ('romantic', 0.0909)],
#  599: [('Drama', 1.0),
#   ('Comedy', 0.9653),
#   ('Action', 0.7515),
#   ('Thriller', 0.5911),
#   ('Adventure', 0.4416),
#   ('Crime', 0.4149),
#   ('Sci-Fi', 0.4139),
#   ('Romance', 0.3634),
#   ('Fantasy', 0.2475),
#   ('Horror', 0.1941),
#   ('Children', 0.1644),
#   ('Animation', 0.1614),
#   ('Mystery', 0.1614),
#   ('War', 0.0832),
#   ('Musical', 0.0683),
#   ('IMAX', 0.0515),
#   ('Documentary', 0.0515),
#   ('Western', 0.0485),
#   ('Film-Noir', 0.0277),
#   ('atmospheric', 0.0208),
#   ('superhero', 0.0178),
#   ('In Netflix queue', 0.0178),
#   ('sci-fi', 0.0149),
#   ('psychology', 0.0139),
#   ('time travel', 0.0129),
#   ('Disney', 0.0129),
#   ('visually appealing', 0.0119),
#   ('twist ending', 0.0109),
#   ('suspense', 0.0109),
#   ('dark comedy', 0.0109),
#   ('thought-provoking', 0.0109),
#   ('quirky', 0.0099),
#   ('space', 0.0099),
#   ('aliens', 0.0099),
#   ('surreal', 0.0099),
#   ('Shakespeare', 0.0089),
#   ('mindfuck', 0.0089),
#   ('funny', 0.0089),
#   ('heist', 0.0089),
#   ('dreamlike', 0.0089),
#   ('anime', 0.0089),
#   ('politics', 0.0079),
#   ('action', 0.0079),
#   ('satire', 0.0079),
#   ('tense', 0.0079),
#   ('robots', 0.0079),
#   ('music', 0.0079),
#   ('martial arts', 0.0079),
#   ('Mafia', 0.0069),
#   ('high school', 0.0069)],
#  600: [('Comedy', 1.0),
#   ('Drama', 0.8042),
#   ('Romance', 0.4386),
#   ('Adventure', 0.4047),
#   ('Thriller', 0.3603),
#   ('Action', 0.3446),
#   ('Fantasy', 0.329),
#   ('Children', 0.3003),
#   ('Sci-Fi', 0.2559),
#   ('Crime', 0.201),
#   ('Horror', 0.1697),
#   ('Animation', 0.1619),
#   ('Musical', 0.1593),
#   ('Mystery', 0.1044),
#   ('War', 0.0574),
#   ('Disney', 0.0522),
#   ('Documentary', 0.0313),
#   ('IMAX', 0.0287),
#   ('Western', 0.0287),
#   ('In Netflix queue', 0.0235),
#   ('psychology', 0.0235),
#   ('superhero', 0.0209),
#   ('time travel', 0.0183),
#   ('twist ending', 0.0183),
#   ('space', 0.0183),
#   ('anime', 0.0183),
#   ('high school', 0.0183),
#   ('remake', 0.0157),
#   ('music', 0.0157),
#   ('quirky', 0.0157),
#   ('Stephen King', 0.0157),
#   ('dark comedy', 0.0157),
#   ('surreal', 0.0157),
#   ('sci-fi', 0.0131),
#   ('Christmas', 0.0131),
#   ('bittersweet', 0.0131),
#   ('thought-provoking', 0.0131),
#   ('suspense', 0.0131),
#   ('satire', 0.0131),
#   ('sequel', 0.0131),
#   ('tense', 0.0131),
#   ('atmospheric', 0.0131),
#   ('martial arts', 0.0131),
#   ('Magic', 0.0131),
#   ('mindfuck', 0.0104),
#   ('revenge', 0.0104),
#   ('classic', 0.0104),
#   ('great soundtrack', 0.0104),
#   ('space opera', 0.0104),
#   ('twins', 0.0104)],
#  601: [('Drama', 1.0),
#   ('Adventure', 0.8163),
#   ('Action', 0.7551),
#   ('Thriller', 0.5102),
#   ('Animation', 0.4286),
#   ('Comedy', 0.4082),
#   ('Sci-Fi', 0.4082),
#   ('Fantasy', 0.3878),
#   ('Children', 0.3673),
#   ('Crime', 0.3469),
#   ('Romance', 0.3265),
#   ('Mystery', 0.2449),
#   ('IMAX', 0.2041),
#   ('thought-provoking', 0.1633),
#   ('War', 0.1633),
#   ('twist ending', 0.1224),
#   ('Leonardo DiCaprio', 0.1224),
#   ('atmospheric', 0.102),
#   ('imdb top 250', 0.0816),
#   ('emotional', 0.0816),
#   ('bittersweet', 0.0816),
#   ('sci-fi', 0.0816),
#   ('anime', 0.0816),
#   ('dreamlike', 0.0816),
#   ('visually appealing', 0.0816),
#   ('fun', 0.0612),
#   ('mystery', 0.0612),
#   ('heist', 0.0612),
#   ('mindfuck', 0.0612),
#   ('suspense', 0.0612),
#   ('adventure', 0.0612),
#   ('inspirational', 0.0612),
#   ('Pixar', 0.0612),
#   ('philosophy', 0.0612),
#   ('psychology', 0.0612),
#   ('fantasy world', 0.0612),
#   ('surreal', 0.0612),
#   ('animation', 0.0612),
#   ('funny', 0.0612),
#   ('Disney', 0.0612),
#   ('psychological', 0.0612),
#   ('Tolkein', 0.0612),
#   ('intelligent', 0.0612),
#   ('superhero', 0.0612),
#   ('Martin Scorsese', 0.0612),
#   ('Morgan Freeman', 0.0408),
#   ('Holocaust', 0.0408),
#   ('Mafia', 0.0408),
#   ('photography', 0.0408),
#   ('good dialogue', 0.0408)],
#  602: [('Drama', 1.0),
#   ('Thriller', 0.75),
#   ('Action', 0.6176),
#   ('Comedy', 0.5882),
#   ('Adventure', 0.4265),
#   ('Crime', 0.4118),
#   ('Romance', 0.3676),
#   ('Sci-Fi', 0.2206),
#   ('Mystery', 0.1618),
#   ('Children', 0.1176),
#   ('Fantasy', 0.1029),
#   ('War', 0.1029),
#   ('Western', 0.0882),
#   ('Horror', 0.0441),
#   ('time travel', 0.0441),
#   ('twist ending', 0.0441),
#   ('dark comedy', 0.0441),
#   ('disturbing', 0.0441),
#   ('John Grisham', 0.0441),
#   ('president', 0.0294),
#   ('politics', 0.0294),
#   ('serial killer', 0.0294),
#   ('mindfuck', 0.0294),
#   ('suspense', 0.0294),
#   ('prostitution', 0.0294),
#   ('space', 0.0294),
#   ('IMAX', 0.0294),
#   ('superhero', 0.0294),
#   ('Film-Noir', 0.0294),
#   ('mental illness', 0.0294),
#   ('psychology', 0.0294),
#   ('Stephen King', 0.0294),
#   ('sci-fi', 0.0294),
#   ('great soundtrack', 0.0294),
#   ('prison', 0.0294),
#   ('hit men', 0.0294),
#   ('drama', 0.0294),
#   ('touching', 0.0294),
#   ('assassination', 0.0294),
#   ('Musical', 0.0294),
#   ('Animation', 0.0294),
#   ('gothic', 0.0294),
#   ('based on a TV show', 0.0294),
#   ('based on a true story', 0.0294),
#   ('game', 0.0147),
#   ('magic board game', 0.0147),
#   ('Robin Williams', 0.0147),
#   ('fantasy', 0.0147),
#   ('Mafia', 0.0147),
#   ('Hollywood', 0.0147)],
#  603: [('Drama', 1.0),
#   ('Comedy', 0.6007),
#   ('Romance', 0.3993),
#   ('Thriller', 0.3586),
#   ('Action', 0.2828),
#   ('Crime', 0.2662),
#   ('Adventure', 0.1885),
#   ('Sci-Fi', 0.146),
#   ('Mystery', 0.1442),
#   ('Horror', 0.1423),
#   ('Fantasy', 0.0869),
#   ('Musical', 0.0591),
#   ('War', 0.0573),
#   ('Documentary', 0.0518),
#   ('Film-Noir', 0.0425),
#   ('In Netflix queue', 0.037),
#   ('Western', 0.0351),
#   ('Children', 0.0296),
#   ('imdb top 250', 0.0148),
#   ('superhero', 0.0129),
#   ('suspense', 0.0129),
#   ('Mafia', 0.0111),
#   ('twist ending', 0.0111),
#   ('psychology', 0.0111),
#   ('high school', 0.0111),
#   ('time travel', 0.0092),
#   ('remake', 0.0092),
#   ('mindfuck', 0.0092),
#   ('music', 0.0092),
#   ('sci-fi', 0.0092),
#   ('dark comedy', 0.0092),
#   ('disturbing', 0.0092),
#   ('Vietnam', 0.0092),
#   ('atmospheric', 0.0092),
#   ('adultery', 0.0092),
#   ('Stephen King', 0.0092),
#   ('spoof', 0.0092),
#   ('martial arts', 0.0092),
#   ('Animation', 0.0074),
#   ('Jane Austen', 0.0074),
#   ('crime', 0.0074),
#   ('assassination', 0.0074),
#   ('space', 0.0074),
#   ('drugs', 0.0074),
#   ('emotional', 0.0074),
#   ('thought-provoking', 0.0074),
#   ('politics', 0.0074),
#   ('Coen Brothers', 0.0074),
#   ('religion', 0.0074),
#   ('aliens', 0.0074)],
#  604: [('Drama', 1.0),
#   ('Action', 0.8205),
#   ('Thriller', 0.7692),
#   ('Comedy', 0.7436),
#   ('Horror', 0.5641),
#   ('Adventure', 0.4872),
#   ('Crime', 0.4872),
#   ('Sci-Fi', 0.4359),
#   ('Romance', 0.359),
#   ('Children', 0.3333),
#   ('Fantasy', 0.3077),
#   ('Animation', 0.1795),
#   ('Mystery', 0.1026),
#   ('Disney', 0.1026),
#   ('Musical', 0.1026),
#   ('gothic', 0.0769),
#   ('Christmas', 0.0769),
#   ('remake', 0.0513),
#   ('Jane Austen', 0.0513),
#   ('time travel', 0.0513),
#   ('War', 0.0513),
#   ('assassination', 0.0513),
#   ('superhero', 0.0513),
#   ('mental illness', 0.0513),
#   ('psychology', 0.0513),
#   ('dark comedy', 0.0513),
#   ('hit men', 0.0513),
#   ('drama', 0.0513),
#   ('disturbing', 0.0513),
#   ('IMAX', 0.0513),
#   ('Western', 0.0513),
#   ('pixar', 0.0256),
#   ('fun', 0.0256),
#   ('game', 0.0256),
#   ('magic board game', 0.0256),
#   ('Robin Williams', 0.0256),
#   ('fantasy', 0.0256),
#   ('pregnancy', 0.0256),
#   ('president', 0.0256),
#   ('politics', 0.0256),
#   ('serial killer', 0.0256),
#   ('alcoholism', 0.0256),
#   ('Bruce Willis', 0.0256),
#   ('Post apocalyptic', 0.0256),
#   ('Brad Pitt', 0.0256),
#   ('post-apocalyptic', 0.0256),
#   ('mindfuck', 0.0256),
#   ('twist ending', 0.0256),
#   ('pigs', 0.0256),
#   ('villain nonexistent or not needed for good story', 0.0256)],
#  605: [('Fantasy', 1.0),
#   ('Adventure', 0.7681),
#   ('Comedy', 0.6449),
#   ('Action', 0.5),
#   ('Romance', 0.4275),
#   ('Drama', 0.4275),
#   ('Children', 0.3841),
#   ('Animation', 0.1884),
#   ('Sci-Fi', 0.1884),
#   ('Musical', 0.1884),
#   ('Thriller', 0.1812),
#   ('Horror', 0.1087),
#   ('IMAX', 0.1014),
#   ('Crime', 0.0797),
#   ('Disney', 0.0725),
#   ('War', 0.0652),
#   ('Mystery', 0.058),
#   ('superhero', 0.0435),
#   ('Magic', 0.0362),
#   ('fantasy', 0.029),
#   ('space', 0.029),
#   ('time travel', 0.029),
#   ('Wizards', 0.029),
#   ('In Netflix queue', 0.0217),
#   ('sci-fi', 0.0217),
#   ('great soundtrack', 0.0217),
#   ('space opera', 0.0217),
#   ('Western', 0.0217),
#   ('gothic', 0.0217),
#   ('fantasy world', 0.0217),
#   ('anime', 0.0217),
#   ('Tolkein', 0.0217),
#   ('Robin Williams', 0.0145),
#   ('beautiful scenery', 0.0145),
#   ('classic', 0.0145),
#   ('darth vader', 0.0145),
#   ('luke skywalker', 0.0145),
#   ('overrated', 0.0145),
#   ('robots', 0.0145),
#   ('swashbuckler', 0.0145),
#   ('high school', 0.0145),
#   ('quirky', 0.0145),
#   ('Studio Ghibli', 0.0145),
#   ('religion', 0.0145),
#   ('animation', 0.0145),
#   ('movie business', 0.0145),
#   ('comic book', 0.0145),
#   ('stylized', 0.0145),
#   ('06 Oscar Nominated Best Movie - Animation', 0.0145),
#   ('pixar', 0.0072)],
#  606: [('Drama', 1.0),
#   ('Comedy', 0.6032),
#   ('Romance', 0.5086),
#   ('Thriller', 0.2851),
#   ('Action', 0.2163),
#   ('Adventure', 0.2106),
#   ('Crime', 0.1905),
#   ('Fantasy', 0.139),
#   ('Mystery', 0.1304),
#   ('Sci-Fi', 0.1132),
#   ('War', 0.0931),
#   ('Horror', 0.0745),
#   ('Children', 0.0702),
#   ('Musical', 0.063),
#   ('Animation', 0.0602),
#   ('In Netflix queue', 0.0473),
#   ('Western', 0.0244),
#   ('IMAX', 0.0229),
#   ('atmospheric', 0.0143),
#   ('psychology', 0.0115),
#   ('sci-fi', 0.0115),
#   ('imdb top 250', 0.0115),
#   ('Film-Noir', 0.0115),
#   ('twist ending', 0.01),
#   ('suspense', 0.01),
#   ('disturbing', 0.01),
#   ('adultery', 0.01),
#   ('anime', 0.01),
#   ('surreal', 0.01),
#   ('martial arts', 0.01),
#   ('heist', 0.0086),
#   ('journalism', 0.0086),
#   ('dark comedy', 0.0086),
#   ('Shakespeare', 0.0086),
#   ('thought-provoking', 0.0086),
#   ('Disney', 0.0086),
#   ('music', 0.0086),
#   ('religion', 0.0086),
#   ('remake', 0.0072),
#   ('politics', 0.0072),
#   ('time travel', 0.0072),
#   ('mindfuck', 0.0072),
#   ('wedding', 0.0072),
#   ('Leonardo DiCaprio', 0.0072),
#   ('space', 0.0072),
#   ('tense', 0.0072),
#   ('Stephen King', 0.0072),
#   ('men in drag', 0.0072),
#   ('bittersweet', 0.0072),
#   ('Vietnam', 0.0072)],
#  607: [('Drama', 1.0),
#   ('Action', 0.878),
#   ('Thriller', 0.7439),
#   ('Comedy', 0.6707),
#   ('Adventure', 0.5488),
#   ('Sci-Fi', 0.439),
#   ('Horror', 0.4268),
#   ('Romance', 0.3537),
#   ('Crime', 0.3293),
#   ('Fantasy', 0.2561),
#   ('Children', 0.2317),
#   ('Mystery', 0.2073),
#   ('Animation', 0.0732),
#   ('War', 0.0732),
#   ('superhero', 0.061),
#   ('Stephen King', 0.061),
#   ('Musical', 0.061),
#   ('spoof', 0.061),
#   ('martial arts', 0.061),
#   ('space', 0.0488),
#   ('sci-fi', 0.0488),
#   ('time travel', 0.0488),
#   ('aliens', 0.0488),
#   ('Disney', 0.0488),
#   ('space opera', 0.0366),
#   ('disturbing', 0.0366),
#   ('suspense', 0.0366),
#   ('sequel', 0.0366),
#   ('tense', 0.0366),
#   ('slasher', 0.0366),
#   ('twist ending', 0.0366),
#   ('mindfuck', 0.0366),
#   ('ghosts', 0.0366),
#   ('president', 0.0244),
#   ('politics', 0.0244),
#   ('alcoholism', 0.0244),
#   ('classic', 0.0244),
#   ('darth vader', 0.0244),
#   ('luke skywalker', 0.0244),
#   ('great soundtrack', 0.0244),
#   ('action', 0.0244),
#   ('hit men', 0.0244),
#   ('based on a true story', 0.0244),
#   ('Western', 0.0244),
#   ('robots', 0.0244),
#   ('psychology', 0.0244),
#   ('Coen Brothers', 0.0244),
#   ('Mafia', 0.0244),
#   ('gangsters', 0.0244),
#   ('suspenseful', 0.0244)],
#  608: [('Comedy', 1.0),
#   ('Drama', 0.7887),
#   ('Action', 0.7803),
#   ('Thriller', 0.7296),
#   ('Adventure', 0.5099),
#   ('Sci-Fi', 0.4704),
#   ('Crime', 0.4113),
#   ('Fantasy', 0.3127),
#   ('Romance', 0.2986),
#   ('Horror', 0.2732),
#   ('Children', 0.2479),
#   ('Mystery', 0.1944),
#   ('Animation', 0.1549),
#   ('Musical', 0.093),
#   ('War', 0.0535),
#   ('IMAX', 0.0338),
#   ('Disney', 0.0338),
#   ('superhero', 0.031),
#   ('Western', 0.031),
#   ('time travel', 0.0282),
#   ('psychology', 0.0282),
#   ('mindfuck', 0.0254),
#   ('twist ending', 0.0254),
#   ('sci-fi', 0.0254),
#   ('aliens', 0.0254),
#   ('suspense', 0.0225),
#   ('dark comedy', 0.0225),
#   ('thought-provoking', 0.0197),
#   ('robots', 0.0197),
#   ('Mafia', 0.0169),
#   ('space', 0.0169),
#   ('quirky', 0.0169),
#   ('atmospheric', 0.0169),
#   ('spoof', 0.0169),
#   ('religion', 0.0169),
#   ('crime', 0.0169),
#   ('Documentary', 0.0169),
#   ('high school', 0.0141),
#   ('heist', 0.0141),
#   ('revenge', 0.0141),
#   ('stylized', 0.0141),
#   ('satire', 0.0141),
#   ('tense', 0.0141),
#   ('imdb top 250', 0.0141),
#   ('disturbing', 0.0141),
#   ('cult film', 0.0141),
#   ('violence', 0.0141),
#   ('dreamlike', 0.0141),
#   ('sequel', 0.0141),
#   ('comedy', 0.0141)],
#  609: [('Drama', 1.0),
#   ('Thriller', 0.7368),
#   ('Action', 0.5789),
#   ('Adventure', 0.5263),
#   ('Comedy', 0.3684),
#   ('Crime', 0.3158),
#   ('Sci-Fi', 0.2632),
#   ('Romance', 0.2632),
#   ('War', 0.2105),
#   ('Children', 0.1053),
#   ('Documentary', 0.1053),
#   ('Horror', 0.1053),
#   ('Shakespeare', 0.1053),
#   ('pixar', 0.0526),
#   ('fun', 0.0526),
#   ('Animation', 0.0526),
#   ('Fantasy', 0.0526),
#   ('Medieval', 0.0526),
#   ('Oscar (Best Cinematography)', 0.0526),
#   ('Scotland', 0.0526),
#   ('historical', 0.0526),
#   ('mel gibson', 0.0526),
#   ('sword fight', 0.0526),
#   ('beautiful scenery', 0.0526),
#   ('epic', 0.0526),
#   ('inspirational', 0.0526),
#   ('revenge', 0.0526),
#   ('Holocaust', 0.0526),
#   ('moon', 0.0526),
#   ('NASA', 0.0526),
#   ('space', 0.0526),
#   ('IMAX', 0.0526),
#   ('submarine', 0.0526),
#   ('computers', 0.0526),
#   ('brutality', 0.0526),
#   ('psychedelic', 0.0526),
#   ('controversial', 0.0526),
#   ('stylized', 0.0526),
#   ('satire', 0.0526),
#   ('dark comedy', 0.0526),
#   ('non-linear', 0.0526),
#   ('Tarantino', 0.0526),
#   ('hit men', 0.0526),
#   ('good dialogue', 0.0526),
#   ('great soundtrack', 0.0526),
#   ('Quentin Tarantino', 0.0526),
#   ('cult film', 0.0526),
#   ('drugs', 0.0526),
#   ('1990s', 0.0526),
#   ('AWESOME', 0.0526)],
#  610: [('Action', 1.0),
#   ('Thriller', 0.9846),
#   ('Drama', 0.9247),
#   ('Comedy', 0.7934),
#   ('Horror', 0.5849),
#   ('Crime', 0.527),
#   ('Adventure', 0.5154),
#   ('Sci-Fi', 0.4846),
#   ('Fantasy', 0.2915),
#   ('Mystery', 0.2317),
#   ('Romance', 0.2297),
#   ('IMAX', 0.1583),
#   ('Animation', 0.1274),
#   ('Children', 0.1081),
#   ('War', 0.0907),
#   ('Western', 0.0637),
#   ('atmospheric', 0.0347),
#   ('superhero', 0.027),
#   ('sci-fi', 0.027),
#   ('Musical', 0.027),
#   ('visually appealing', 0.0251),
#   ('thought-provoking', 0.0212),
#   ('twist ending', 0.0193),
#   ('suspense', 0.0193),
#   ('action', 0.0193),
#   ('psychology', 0.0193),
#   ('dark comedy', 0.0193),
#   ('Film-Noir', 0.0193),
#   ('surreal', 0.0193),
#   ('mindfuck', 0.0174),
#   ('comedy', 0.0174),
#   ('quirky', 0.0174),
#   ('time travel', 0.0154),
#   ('heist', 0.0154),
#   ('funny', 0.0154),
#   ('dark', 0.0154),
#   ('bittersweet', 0.0135),
#   ('robots', 0.0135),
#   ('dreamlike', 0.0135),
#   ('Coen Brothers', 0.0135),
#   ('black comedy', 0.0135),
#   ('satire', 0.0135),
#   ('religion', 0.0135),
#   ('crime', 0.0135),
#   ('cinematography', 0.0135),
#   ('Leonardo DiCaprio', 0.0135),
#   ('space', 0.0116),
#   ('touching', 0.0116),
#   ('imdb top 250', 0.0116),
#   ('disturbing', 0.0116)]}

# %%
train_dict = dict()
for i in train.userId.unique():
    train_dict[i] = {}
    for j in train[train.userId == i].movieId:
        train_dict[i][j] = train[(train.userId == i) & (train.movieId == j)].rating.values[0]

# %%
test_dict = dict()
for i in test.userId.unique():
    test_dict[i] = {}
    for j in test[test.userId == i].movieId:
        test_dict[i][j] = test[(test.userId == i) & (test.movieId == j)].rating.values[0]

# %%
# 为用户产生推荐结果
recommendation = {}
for uid, interest_words in tqdm(user_profile.items()):
    result_table = {}   # 电影id: [0.2, 0.5]
    for interest_word, interest_weight in interest_words:
        related_movies = inverted_table[interest_word]
        for mid, relate_weight in related_movies:
            if mid in train_dict[uid]:
                continue
            _ = result_table.get(mid, [])
            _.append(interest_weight)    #只考虑用户的兴趣程度
            # _.append(relate_weight)   # 只考虑兴趣词与电影的关联程度
            # _.append(interest_weight * relate_weight)     # 二者都考虑
            result_table.setdefault(mid, _)


    rs_result = map(lambda x: (x[0], sum(x[1])), result_table.items())
    rs_result = sorted(rs_result, key=lambda x: x[1], reverse=True)
    recommendation[uid] = {i[0]:i[1] for i in rs_result}
    # break
# Out:
#   0%|          | 0/610 [00:00<?, ?it/s]

# %%
hit = 0
for item, w in sorted(recommendation[1].items(), key=lambda x: x[1], reverse=True)[0:nitems]:
    if item in test_dict[1]:
        hit += 1

# %%
nitems = 10
hit = 0
mae = 0
n_recall = 0
n_precision = 0
n_mae = 0

for user in train_dict:
    test_items = test_dict.get(user, {})
    rank = recommendation[user]
    for item, w in sorted(rank.items(), key=lambda x: x[1], reverse=True)[0:10]:
        if item in test_items:
            hit += 1
            mae += abs(w - test_items[item])
            n_mae += 1
    n_recall += len(test_items)
    n_precision += nitems

# %%
print("精准率：", hit / (1.0 * n_precision))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 print("精准率：", hit / (1.0 * n_precision))
#
# ZeroDivisionError: float division by zero

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [136], in <cell line: 1>()
# ----> 1 test_dict[1][187031]
#
# KeyError: 187031

# %%
user
# Out:
# 431

# %%
recommendation[1][81132]
# Out:
# 5.2
